# %% [markdown]
# <h2> Initialization </h2>

# %%
import tensorflow as tf
import tensorflow.keras as keras

import numpy as np
import os
import csv
import pandas as pd
import math

from skimage.io import imread
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

from matplotlib import image
from matplotlib import pyplot
from keras.preprocessing.image import ImageDataGenerator

from matplotlib import image

import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

import random
print("Tensorflow version %s" %tf.__version__)


device_name = tf.test.gpu_device_name()

if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
if  tf.test.is_gpu_available():
    device_str = "/device:GPU:0"
else:
    device_str = "/cpu:0"

folders=["/BENIGN/benign_","/CANCER/cancer_"]#,"/NORMAL(PNG)/normal_"]
directory=r'Z:/Dataset/NN_Dataset/DDSM/DDSM_Resized/CrossVal'
case=""
left_cc=""
left_mlo=""
right_cc=""
right_mlo=""
lb=0
lm=0
rb=0
rm=0

in_channel=3
img_rows, img_cols=512, 384

AUTOTUNE = tf.data.experimental.AUTOTUNE

training="training"
test="test"
validation="validation"

img_size=300
epoch=20
regl2 = 0.0001
lr=0.0001
for_step=15
# Out:
# Using TensorFlow backend.
# Tensorflow version 2.0.0
# Found GPU at: /device:GPU:0

# %% [markdown]
# <h2> Cross Val CSVs Generation - done only once </h2>

# %%
numbers= ['01/','02/','03/','04/','05/','06/','07/','08/','09/','10/']
numbersCV =[]



def createCrossVal():
    #select 5 couples of validationSets
    N = ['01/','02/','03/','04/','05/','06/','07/','08/','09/','10/']
    
    R=0
    while R<5:
        random.shuffle(N)
        first = random.choice(numbers)
        numbers.remove(first)
        second = random.choice(numbers)
        numbers.remove(second)
       
        tmp = []
        
        for e in N:
            if e == first or e == second:
                continue
            tmp.append(e)
        if len(tmp)==8:
            tmp.append(first)
            tmp.append(second)
            numbersCV.append(tmp)
            
        R=R+1
    return

createCrossVal()
print(numbersCV)
numbers1 = numbersCV[4]
numbers1 = numbers1[0:8]
numbers2= numbersCV[4]
numbers2 = numbers2[8:10]
folders=["/BENIGN(PNG)/benign_","/CANCER(PNG)/cancer_"]
directory2=r'Z:/Dataset/NN_Dataset/DDSM/DDSM_Resized'
# Out:
# [['08/', '06/', '02/', '10/', '03/', '09/', '05/', '04/', '07/', '01/'], ['10/', '01/', '08/', '05/', '04/', '06/', '07/', '02/', '09/', '03/'], ['08/', '10/', '02/', '01/', '04/', '07/', '09/', '03/', '05/', '06/'], ['07/', '05/', '02/', '01/', '03/', '06/', '09/', '08/', '04/', '10/'], ['07/', '06/', '03/', '10/', '05/', '09/', '04/', '01/', '08/', '02/']]

# %% [markdown]
# <h3 style="color:blue"> CROSS VAL 1/5</h3>

# %%
col=["case","left_cc","left_mlo","right_cc","right_mlo","lb","lm","rb","rm"]
dtypes={"case": "str","left_cc": "str","left_mlo": "str","right_cc": "str","right_mlo": "str","lb": "int","lm": "int","rb": "int","rm": "int"}
df_training=pd.read_csv(directory+'/training_1.csv', sep=',', names=col,dtype=dtypes,  header=None)
df_validation=pd.read_csv(directory+'/validation_1.csv', sep=',', names=col,dtype=dtypes,  header=None)
#df_test=pd.read_csv(directory+'/test_r.csv', sep=',', names=col,dtype=dtypes,  header=None)

def read_spectograms(file_paths, img_rows, img_cols, channels):

  images = []
  
  for file_path in file_paths:
    if file_path=="nan":
        continue
    images.append(imread(file_path))
  
  images = np.asarray(images, dtype=np.float32)
  
  # normalize
  images = images / 255
  
  # reshape to match Keras expectaions
  images = images.reshape(images.shape[0], img_rows, img_cols, channels)

  return images


x_train_left_mlo = read_spectograms(df_training.left_mlo.values, img_rows, img_cols, in_channel)
x_train_left_cc= read_spectograms(df_training.left_cc.values, img_rows, img_cols, in_channel)

###Right

x_train_right_mlo = read_spectograms(df_training.right_mlo.values, img_rows, img_cols, in_channel)
x_train_right_cc= read_spectograms(df_training.right_cc.values, img_rows, img_cols, in_channel)

###labels

from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
labels = df_training[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels=labels.values
labels
print(type(labels))

x_validation_left_mlo = read_spectograms(df_validation.left_mlo.values, img_rows, img_cols, in_channel)
x_validation_left_cc= read_spectograms(df_validation.left_cc.values, img_rows, img_cols, in_channel)

x_validation_right_mlo = read_spectograms(df_validation.right_mlo.values, img_rows, img_cols, in_channel)
x_validation_right_cc= read_spectograms(df_validation.right_cc.values, img_rows, img_cols, in_channel)


mlb = MultiLabelBinarizer()
labels_validation = df_validation[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels_validation=labels_validation.values
labels_validation
print(type(labels_validation))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#  V 2

def resnetBlock(inputimage,k=2,striede=1, name=""):

  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(inputimage)


  activation=keras.activations.relu(batch_normalize )

  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(3,3),
    name="",
  padding="same"
  )(activation)

  conv1x1_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(1,1),
    name="",
#    activation=keras.activations.relu
  )(activation)


  batch_normalize_2 = keras.layers.BatchNormalization( axis=-1,name="")(conv3x3_1)

  activation2=keras.activations.relu(batch_normalize_2 )
  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    kernel_size=(3,3),
    name="",
    padding="same"
  )(activation2)

  outputs=keras.layers.Add()([conv3x3_1,conv1x1_1])
  return outputs


def resNetLayers(inputimage,name=""):
  block1=resnetBlock(inputimage,k=16,name="block1")
  #block2=resnetBlock(block1,k=16,name="block2")
  block3=resnetBlock(block1,k=16,striede=2,name="block3")
  #block4=resnetBlock(block3,k=32,name="block4")
  block5=resnetBlock(block3,k=32,striede=2,name="block5")
  pool=keras.layers.AveragePooling2D(
      pool_size=(3,3), strides=2, padding='same', name='' #(3,3)
  )(block5)
  #block6=resnetBlock(block5,k=32,striede=2,name="block6")
  block7=resnetBlock(pool,k=32,striede=2,name="block7")
  #block8=resnetBlock(inputfilter=128,k=128,name="block8")(block7)
  
  #block10=resnetBlock(inputfilter=256,k=256,name="block10")(block9)
  return block7

def singleViewResnet(inputimage, name=""):

  conv7x7=tf.keras.layers.Conv2D(
    filters=16,
    strides=2,
    kernel_size=(5,5),
    name="",
    activation=keras.activations.relu
  )(inputimage)

  pool3x3=keras.layers.AveragePooling2D(
      pool_size=(2,2), strides=2, padding='same', name='' #(3,3)
  )(conv7x7)

  resNetL=resNetLayers(pool3x3,name="")
  print(resNetL.shape)
  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(resNetL)

  relu=keras.activations.relu(batch_normalize)
  
  return relu


def view_wise(img_rows=300, img_cols=300):
  left_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_cc")
  right_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_cc"
  )  

  left_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_mlo"
  )  
  right_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_mlo"
  )

  #cc_resnet=singleViewResnet(name="cc_resnet")
  #mlo_resnet=singleViewResnet(name="mlo_resnet")

  cc_resnet_left=singleViewResnet(left_cc_input)
  cc_resnet_right=singleViewResnet(right_cc_input)

  mlo_resnet_left=singleViewResnet(left_mlo_input)
  mlo_resent_right=singleViewResnet(right_mlo_input)

  avg_pool_cc_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_left)
  avg_pool_cc_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_right)

  avg_pool_mlo_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resnet_left)
  avg_pool_mlo_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resent_right)

  mlo=keras.layers.Concatenate(axis=-1)([avg_pool_mlo_left, avg_pool_mlo_right])
  cc=keras.layers.Concatenate(axis=-1)([avg_pool_cc_left, avg_pool_cc_right])

  mlo_flatten=tf.keras.layers.Flatten()(mlo)
  cc_flatten=tf.keras.layers.Flatten()(cc)

  """
  mlo_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(256,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(mlo_flatten)
    )
  """
  mlo_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_flatten)
        )
      )
  mlo_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_dense1)
        )
      ) 
  
  mlo_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(mlo_dense3)
    )
  
  """
  cc_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(512,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(cc_flatten)
    )
  """
  

  cc_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_flatten)
        )
      )
  cc_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_dense1)
        )
      ) 
 
  cc_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(cc_dense3)
    )
  
  
  
  """mlo_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rb")(mlo_dense2)
  mlo_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rm")(mlo_dense2)
  mlo_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lb")(mlo_dense2)
  mlo_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lm")(mlo_dense2)
  
  cc_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rb")(cc_dense2)
  cc_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rm")(cc_dense2)
  cc_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lb")(cc_dense2)
  cc_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lm")(cc_dense2)
  
  rb_output = keras.layers.Average(name="rb")([mlo_rb,cc_rb])
  rm_output = keras.layers.Average(name="rm")([mlo_rm,cc_rm])
  lb_output = keras.layers.Average(name="lb")([mlo_lb,cc_lb])
  lm_output = keras.layers.Average(name="lm")([mlo_lm,cc_lm])"""

  output=keras.layers.Average(name="outpu")([cc_dense2,mlo_dense2])

  output=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(output)
    )
  
 
  output=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(4,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(output)
    )

  return keras.Model(
      inputs=[left_cc_input, right_cc_input, left_mlo_input, right_mlo_input],
      outputs=output,name="view-wise"
  )
model=view_wise(img_rows, img_cols)
model.summary()
#keras.utils.plot_model(model, "/gdrive/My Drive/Colab_Notebooks/NNPROJECT/image_Net/view-wise.png", show_shapes=True, expand_nested=False)
# Out:
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# Model: "view-wise"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_cc (InputLayer)            [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# right_cc (InputLayer)           [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# left_mlo (InputLayer)           [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# right_mlo (InputLayer)          [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 254, 190, 16) 1216        left_cc[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 254, 190, 16) 1216        right_cc[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 254, 190, 16) 1216        left_mlo[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 254, 190, 16) 1216        right_mlo[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 127, 95, 16)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 127, 95, 16)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 127, 95, 16)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 127, 95, 16)  0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 127, 95, 16)  64          average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 127, 95, 16)  64          average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 127, 95, 16)  64          average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 127, 95, 16)  64          average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu (TensorFlowOpL [(None, 127, 95, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_9 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_18 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_27 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 127, 95, 16)  2320        tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 127, 95, 16)  64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 127, 95, 16)  64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 127, 95, 16)  64          conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 127, 95, 16)  64          conv2d_40[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_1 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_10 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_19 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_28 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 127, 95, 16)  2320        tf_op_layer_Relu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 127, 95, 16)  272         tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_28[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_27[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 127, 95, 16)  0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 127, 95, 16)  0           conv2d_16[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 127, 95, 16)  0           conv2d_29[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 127, 95, 16)  0           conv2d_42[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 127, 95, 16)  64          add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 127, 95, 16)  64          add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 127, 95, 16)  64          add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 127, 95, 16)  64          add_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_2 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_11 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_20 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_29 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 48, 16)   2320        tf_op_layer_Relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 48, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 48, 16)   64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 48, 16)   64          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 48, 16)   64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_3 (TensorFlowO [(None, 64, 48, 16)] 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_12 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_21 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_30 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 48, 16)   2320        tf_op_layer_Relu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 48, 16)   272         tf_op_layer_Relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_30[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 48, 16)   0           conv2d_6[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 48, 16)   0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 48, 16)   0           conv2d_32[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 48, 16)   0           conv2d_45[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 48, 16)   64          add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 48, 16)   64          add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 48, 16)   64          add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 48, 16)   64          add_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_4 (TensorFlowO [(None, 64, 48, 16)] 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_13 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_22 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_31 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 24, 32)   4640        tf_op_layer_Relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 24, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 24, 32)   128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 24, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 24, 32)   128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_5 (TensorFlowO [(None, 32, 24, 32)] 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_14 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_23 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_32 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 24, 32)   9248        tf_op_layer_Relu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 24, 32)   544         tf_op_layer_Relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_32[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_31[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 24, 32)   0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 24, 32)   0           conv2d_22[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 24, 32)   0           conv2d_35[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 24, 32)   0           conv2d_48[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 16, 12, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 16, 12, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 16, 12, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 16, 12, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 12, 32)   128         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_6 (TensorFlowO [(None, 16, 12, 32)] 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_15 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_24 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_33 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 6, 32)     128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 6, 32)     128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 6, 32)     128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 6, 32)     128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_7 (TensorFlowO [(None, 8, 6, 32)]   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_16 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_25 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_34 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_34[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_33[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 6, 32)     0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 6, 32)     0           conv2d_25[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 6, 32)     0           conv2d_38[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 6, 32)     0           conv2d_51[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 6, 32)     128         add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 6, 32)     128         add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 6, 32)     128         add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 6, 32)     128         add_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_8 (TensorFlowO [(None, 8, 6, 32)]   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_17 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_26 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_35 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 4, 3, 32)     0           tf_op_layer_Relu_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 4, 3, 32)     0           tf_op_layer_Relu_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 4, 3, 32)     0           tf_op_layer_Relu_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 4, 3, 32)     0           tf_op_layer_Relu_35[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 3, 64)     0           average_pooling2d_8[0][0]
#                                                                  average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 3, 64)     0           average_pooling2d_10[0][0]
#                                                                  average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 768)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 768)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2048)         1574912     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         1574912     flatten[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 2048)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 2048)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2048)         0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024)         2098176     dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     dropout[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 1024)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           65600       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           65600       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# outpu (Average)                 (None, 64)           0           dropout_5[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           4160        outpu[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 4)            260         dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 4)            0           dense_7[0][0]
# ==================================================================================================
# Total params: 7,665,220
# Trainable params: 7,663,556
# Non-trainable params: 1,664
# __________________________________________________________________________________________________

# %%
batch_size=32
step_per_epoch=len(x_train_left_mlo)/batch_size

cbks = [tf.keras.callbacks.EarlyStopping(patience=10, monitor="val_loss"),
        tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_auc1",
                    monitor="val_auc",
                    mode='max',
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
                    
        ),
       tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_loss1",
                    monitor="val_loss",
                    
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
       )]

model.compile(#optimizer=keras.optimizers.Adam(lr=0.001),
              #optimizer=keras.optimizers.SGD(lr=0.0005, decay=1e-6, momentum=0.9, nesterov=True),
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005,rho=0.9,momentum=0.9,epsilon=1e-07),
              loss=keras.losses.BinaryCrossentropy(),
              #loss=custom_loss,
              metrics=[tf.keras.metrics.AUC(name="auc"),tf.keras.metrics.BinaryAccuracy(threshold=0.5)]#tf.keras.metrics.BinaryAccuracy(threshold=0.01)]#,
             )

history=model.fit(x={"left_mlo": x_train_left_mlo,
                         "left_cc": x_train_left_cc,
                         "right_mlo":x_train_right_mlo,
                         "right_cc":x_train_right_cc},
                  y=labels.values,
                  epochs=50,verbose=1,
                  callbacks = cbks,
                  validation_data=(
                      {"left_mlo": x_validation_left_mlo,
                         "left_cc": x_validation_left_cc,
                         "right_mlo":x_validation_right_mlo,
                         "right_cc":x_validation_right_cc},
                    labels_validation.values
                  ))

"""y={"lb":labels["lb"],
    "lm":labels["lm"],
    "rm":labels["rm"],
    "rb":labels["rb"]}
    
"""
# Out:
# Train on 978 samples, validate on 268 samples
# Epoch 1/50
# 960/978 [============================>.] - ETA: 0s - loss: 1.1120 - auc: 0.5040 - binary_accuracy: 0.7099
# Epoch 00001: val_auc improved from -inf to 0.50760, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc1
# WARNING:tensorflow:From c:\users\lpatr\.virtualenvs\proj-r1r8_6rp\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc1\assets
#
# Epoch 00001: val_loss improved from inf to 1.06210, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 89s 91ms/sample - loss: 1.1112 - auc: 0.5028 - binary_accuracy: 0.7104 - val_loss: 1.0621 - val_auc: 0.5076 - val_binary_accuracy: 0.7220
# Epoch 2/50
# 960/978 [============================>.] - ETA: 0s - loss: 1.0065 - auc: 0.5262 - binary_accuracy: 0.7367
# Epoch 00002: val_auc did not improve from 0.50760
#
# Epoch 00002: val_loss improved from 1.06210 to 0.98320, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 66s 68ms/sample - loss: 1.0060 - auc: 0.5253 - binary_accuracy: 0.7367 - val_loss: 0.9832 - val_auc: 0.5070 - val_binary_accuracy: 0.7220
# Epoch 3/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.9234 - auc: 0.5619 - binary_accuracy: 0.7370
# Epoch 00003: val_auc did not improve from 0.50760
#
# Epoch 00003: val_loss improved from 0.98320 to 0.90633, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 54s 55ms/sample - loss: 0.9228 - auc: 0.5600 - binary_accuracy: 0.7372 - val_loss: 0.9063 - val_auc: 0.5013 - val_binary_accuracy: 0.7220
# Epoch 4/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.8581 - auc: 0.5809 - binary_accuracy: 0.7362
# Epoch 00004: val_auc did not improve from 0.50760
#
# Epoch 00004: val_loss improved from 0.90633 to 0.86630, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 69s 70ms/sample - loss: 0.8575 - auc: 0.5815 - binary_accuracy: 0.7362 - val_loss: 0.8663 - val_auc: 0.4585 - val_binary_accuracy: 0.7220
# Epoch 5/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.7987 - auc: 0.6136 - binary_accuracy: 0.7357
# Epoch 00005: val_auc improved from 0.50760 to 0.61370, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc1\assets
#
# Epoch 00005: val_loss improved from 0.86630 to 0.79178, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 94s 96ms/sample - loss: 0.7979 - auc: 0.6147 - binary_accuracy: 0.7357 - val_loss: 0.7918 - val_auc: 0.6137 - val_binary_accuracy: 0.7220
# Epoch 6/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.7544 - auc: 0.6204 - binary_accuracy: 0.7354
# Epoch 00006: val_auc did not improve from 0.61370
#
# Epoch 00006: val_loss improved from 0.79178 to 0.77904, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 66s 68ms/sample - loss: 0.7542 - auc: 0.6202 - binary_accuracy: 0.7354 - val_loss: 0.7790 - val_auc: 0.5032 - val_binary_accuracy: 0.7220
# Epoch 7/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.7171 - auc: 0.6304 - binary_accuracy: 0.7372
# Epoch 00007: val_auc did not improve from 0.61370
#
# Epoch 00007: val_loss did not improve from 0.77904
# 978/978 [==============================] - 32s 33ms/sample - loss: 0.7178 - auc: 0.6274 - binary_accuracy: 0.7372 - val_loss: 0.8500 - val_auc: 0.4513 - val_binary_accuracy: 0.7220
# Epoch 8/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.6870 - auc: 0.6442 - binary_accuracy: 0.7357
# Epoch 00008: val_auc did not improve from 0.61370
#
# Epoch 00008: val_loss improved from 0.77904 to 0.70622, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 59s 60ms/sample - loss: 0.6867 - auc: 0.6447 - binary_accuracy: 0.7357 - val_loss: 0.7062 - val_auc: 0.5785 - val_binary_accuracy: 0.7229
# Epoch 9/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.6639 - auc: 0.6469 - binary_accuracy: 0.7362
# Epoch 00009: val_auc did not improve from 0.61370
#
# Epoch 00009: val_loss improved from 0.70622 to 0.69805, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 66s 68ms/sample - loss: 0.6628 - auc: 0.6493 - binary_accuracy: 0.7362 - val_loss: 0.6980 - val_auc: 0.6128 - val_binary_accuracy: 0.7220
# Epoch 10/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.6460 - auc: 0.6512 - binary_accuracy: 0.7344
# Epoch 00010: val_auc did not improve from 0.61370
#
# Epoch 00010: val_loss did not improve from 0.69805
# 978/978 [==============================] - 30s 31ms/sample - loss: 0.6457 - auc: 0.6527 - binary_accuracy: 0.7336 - val_loss: 0.7264 - val_auc: 0.5220 - val_binary_accuracy: 0.7220
# Epoch 11/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.6246 - auc: 0.6651 - binary_accuracy: 0.7365
# Epoch 00011: val_auc improved from 0.61370 to 0.65993, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc1\assets
#
# Epoch 00011: val_loss improved from 0.69805 to 0.64189, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 68s 70ms/sample - loss: 0.6263 - auc: 0.6610 - binary_accuracy: 0.7359 - val_loss: 0.6419 - val_auc: 0.6599 - val_binary_accuracy: 0.7062
# Epoch 12/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.6182 - auc: 0.6527 - binary_accuracy: 0.7354
# Epoch 00012: val_auc did not improve from 0.65993
#
# Epoch 00012: val_loss did not improve from 0.64189
# 978/978 [==============================] - 33s 34ms/sample - loss: 0.6184 - auc: 0.6520 - binary_accuracy: 0.7357 - val_loss: 0.6793 - val_auc: 0.5370 - val_binary_accuracy: 0.7220
# Epoch 13/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.6009 - auc: 0.6640 - binary_accuracy: 0.7370
# Epoch 00013: val_auc did not improve from 0.65993
#
# Epoch 00013: val_loss did not improve from 0.64189
# 978/978 [==============================] - 27s 28ms/sample - loss: 0.6016 - auc: 0.6625 - binary_accuracy: 0.7359 - val_loss: 0.6898 - val_auc: 0.5572 - val_binary_accuracy: 0.7071
# Epoch 14/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5810 - auc: 0.6911 - binary_accuracy: 0.7383
# Epoch 00014: val_auc did not improve from 0.65993
#
# Epoch 00014: val_loss did not improve from 0.64189
# 978/978 [==============================] - 22s 22ms/sample - loss: 0.5839 - auc: 0.6867 - binary_accuracy: 0.7375 - val_loss: 0.6628 - val_auc: 0.5550 - val_binary_accuracy: 0.7071
# Epoch 15/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5793 - auc: 0.6816 - binary_accuracy: 0.7391
# Epoch 00015: val_auc did not improve from 0.65993
#
# Epoch 00015: val_loss did not improve from 0.64189
# 978/978 [==============================] - 21s 21ms/sample - loss: 0.5782 - auc: 0.6834 - binary_accuracy: 0.7395 - val_loss: 0.6988 - val_auc: 0.5327 - val_binary_accuracy: 0.7220
# Epoch 16/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5742 - auc: 0.6787 - binary_accuracy: 0.7385
# Epoch 00016: val_auc did not improve from 0.65993
#
# Epoch 00016: val_loss did not improve from 0.64189
# 978/978 [==============================] - 19s 20ms/sample - loss: 0.5751 - auc: 0.6778 - binary_accuracy: 0.7385 - val_loss: 0.6706 - val_auc: 0.5889 - val_binary_accuracy: 0.7024
# Epoch 17/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5726 - auc: 0.6767 - binary_accuracy: 0.7349
# Epoch 00017: val_auc did not improve from 0.65993
#
# Epoch 00017: val_loss did not improve from 0.64189
# 978/978 [==============================] - 22s 22ms/sample - loss: 0.5726 - auc: 0.6764 - binary_accuracy: 0.7349 - val_loss: 0.6629 - val_auc: 0.5341 - val_binary_accuracy: 0.7118
# Epoch 18/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5727 - auc: 0.6749 - binary_accuracy: 0.7375
# Epoch 00018: val_auc did not improve from 0.65993
#
# Epoch 00018: val_loss improved from 0.64189 to 0.62141, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 53s 54ms/sample - loss: 0.5737 - auc: 0.6729 - binary_accuracy: 0.7377 - val_loss: 0.6214 - val_auc: 0.6217 - val_binary_accuracy: 0.7220
# Epoch 19/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5617 - auc: 0.6850 - binary_accuracy: 0.7401
# Epoch 00019: val_auc did not improve from 0.65993
#
# Epoch 00019: val_loss did not improve from 0.62141
# 978/978 [==============================] - 41s 42ms/sample - loss: 0.5621 - auc: 0.6847 - binary_accuracy: 0.7398 - val_loss: 0.6427 - val_auc: 0.6126 - val_binary_accuracy: 0.7127
# Epoch 20/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5559 - auc: 0.6943 - binary_accuracy: 0.7406
# Epoch 00020: val_auc did not improve from 0.65993
#
# Epoch 00020: val_loss improved from 0.62141 to 0.61898, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 89s 91ms/sample - loss: 0.5568 - auc: 0.6928 - binary_accuracy: 0.7400 - val_loss: 0.6190 - val_auc: 0.5850 - val_binary_accuracy: 0.7146
# Epoch 21/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5584 - auc: 0.6844 - binary_accuracy: 0.7388
# Epoch 00021: val_auc did not improve from 0.65993
#
# Epoch 00021: val_loss did not improve from 0.61898
# 978/978 [==============================] - 47s 48ms/sample - loss: 0.5592 - auc: 0.6830 - binary_accuracy: 0.7390 - val_loss: 0.6353 - val_auc: 0.5536 - val_binary_accuracy: 0.7155
# Epoch 22/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5542 - auc: 0.6926 - binary_accuracy: 0.7404
# Epoch 00022: val_auc did not improve from 0.65993
#
# Epoch 00022: val_loss did not improve from 0.61898
# 978/978 [==============================] - 21s 22ms/sample - loss: 0.5543 - auc: 0.6919 - binary_accuracy: 0.7408 - val_loss: 0.7120 - val_auc: 0.5030 - val_binary_accuracy: 0.6894
# Epoch 23/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5451 - auc: 0.7052 - binary_accuracy: 0.7419
# Epoch 00023: val_auc did not improve from 0.65993
#
# Epoch 00023: val_loss did not improve from 0.61898
# 978/978 [==============================] - 22s 22ms/sample - loss: 0.5444 - auc: 0.7064 - binary_accuracy: 0.7421 - val_loss: 0.6841 - val_auc: 0.5347 - val_binary_accuracy: 0.6968
# Epoch 24/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5479 - auc: 0.7041 - binary_accuracy: 0.7440
# Epoch 00024: val_auc did not improve from 0.65993
#
# Epoch 00024: val_loss did not improve from 0.61898
# 978/978 [==============================] - 21s 21ms/sample - loss: 0.5487 - auc: 0.7018 - binary_accuracy: 0.7441 - val_loss: 0.6262 - val_auc: 0.5722 - val_binary_accuracy: 0.7155
# Epoch 25/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5508 - auc: 0.6973 - binary_accuracy: 0.7380
# Epoch 00025: val_auc did not improve from 0.65993
#
# Epoch 00025: val_loss did not improve from 0.61898
# 978/978 [==============================] - 20s 20ms/sample - loss: 0.5507 - auc: 0.6972 - binary_accuracy: 0.7380 - val_loss: 0.6952 - val_auc: 0.5136 - val_binary_accuracy: 0.6884
# Epoch 26/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5416 - auc: 0.7083 - binary_accuracy: 0.7406
# Epoch 00026: val_auc did not improve from 0.65993
#
# Epoch 00026: val_loss did not improve from 0.61898
# 978/978 [==============================] - 24s 25ms/sample - loss: 0.5411 - auc: 0.7085 - binary_accuracy: 0.7411 - val_loss: 0.6531 - val_auc: 0.5947 - val_binary_accuracy: 0.7099
# Epoch 27/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5452 - auc: 0.7047 - binary_accuracy: 0.7451
# Epoch 00027: val_auc did not improve from 0.65993
#
# Epoch 00027: val_loss improved from 0.61898 to 0.60463, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 42s 43ms/sample - loss: 0.5453 - auc: 0.7043 - binary_accuracy: 0.7446 - val_loss: 0.6046 - val_auc: 0.6237 - val_binary_accuracy: 0.7024
# Epoch 28/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5393 - auc: 0.7158 - binary_accuracy: 0.7461
# Epoch 00028: val_auc did not improve from 0.65993
#
# Epoch 00028: val_loss did not improve from 0.60463
# 978/978 [==============================] - 21s 22ms/sample - loss: 0.5394 - auc: 0.7154 - binary_accuracy: 0.7462 - val_loss: 0.6477 - val_auc: 0.6124 - val_binary_accuracy: 0.6856
# Epoch 29/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5281 - auc: 0.7343 - binary_accuracy: 0.7484
# Epoch 00029: val_auc did not improve from 0.65993
#
# Epoch 00029: val_loss did not improve from 0.60463
# 978/978 [==============================] - 20s 21ms/sample - loss: 0.5300 - auc: 0.7308 - binary_accuracy: 0.7485 - val_loss: 0.6492 - val_auc: 0.6085 - val_binary_accuracy: 0.7034
# Epoch 30/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5257 - auc: 0.7329 - binary_accuracy: 0.7531
# Epoch 00030: val_auc did not improve from 0.65993
#
# Epoch 00030: val_loss did not improve from 0.60463
# 978/978 [==============================] - 19s 19ms/sample - loss: 0.5268 - auc: 0.7306 - binary_accuracy: 0.7531 - val_loss: 0.6327 - val_auc: 0.6377 - val_binary_accuracy: 0.7127
# Epoch 31/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5364 - auc: 0.7272 - binary_accuracy: 0.7445
# Epoch 00031: val_auc did not improve from 0.65993
#
# Epoch 00031: val_loss did not improve from 0.60463
# 978/978 [==============================] - 25s 26ms/sample - loss: 0.5378 - auc: 0.7243 - binary_accuracy: 0.7444 - val_loss: 0.6657 - val_auc: 0.6024 - val_binary_accuracy: 0.6782
# Epoch 32/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5340 - auc: 0.7212 - binary_accuracy: 0.7471
# Epoch 00032: val_auc did not improve from 0.65993
#
# Epoch 00032: val_loss did not improve from 0.60463
# 978/978 [==============================] - 22s 23ms/sample - loss: 0.5336 - auc: 0.7214 - binary_accuracy: 0.7477 - val_loss: 0.6231 - val_auc: 0.6363 - val_binary_accuracy: 0.7164
# Epoch 33/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5324 - auc: 0.7230 - binary_accuracy: 0.7510
# Epoch 00033: val_auc did not improve from 0.65993
#
# Epoch 00033: val_loss did not improve from 0.60463
# 978/978 [==============================] - 22s 23ms/sample - loss: 0.5320 - auc: 0.7236 - binary_accuracy: 0.7510 - val_loss: 0.7215 - val_auc: 0.5408 - val_binary_accuracy: 0.6838
# Epoch 34/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5261 - auc: 0.7385 - binary_accuracy: 0.7510
# Epoch 00034: val_auc did not improve from 0.65993
#
# Epoch 00034: val_loss did not improve from 0.60463
# 978/978 [==============================] - 52s 53ms/sample - loss: 0.5255 - auc: 0.7392 - binary_accuracy: 0.7510 - val_loss: 0.6294 - val_auc: 0.6559 - val_binary_accuracy: 0.7006
# Epoch 35/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5414 - auc: 0.7139 - binary_accuracy: 0.7432
# Epoch 00035: val_auc did not improve from 0.65993
#
# Epoch 00035: val_loss did not improve from 0.60463
# 978/978 [==============================] - 43s 44ms/sample - loss: 0.5401 - auc: 0.7160 - binary_accuracy: 0.7434 - val_loss: 0.6265 - val_auc: 0.6417 - val_binary_accuracy: 0.6978
# Epoch 36/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5241 - auc: 0.7412 - binary_accuracy: 0.7505
# Epoch 00036: val_auc improved from 0.65993 to 0.69439, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc1\assets
#
# Epoch 00036: val_loss improved from 0.60463 to 0.58245, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss1\assets
# 978/978 [==============================] - 133s 136ms/sample - loss: 0.5239 - auc: 0.7420 - binary_accuracy: 0.7505 - val_loss: 0.5825 - val_auc: 0.6944 - val_binary_accuracy: 0.7146
# Epoch 37/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5176 - auc: 0.7536 - binary_accuracy: 0.7521
# Epoch 00037: val_auc did not improve from 0.69439
#
# Epoch 00037: val_loss did not improve from 0.58245
# 978/978 [==============================] - 56s 57ms/sample - loss: 0.5168 - auc: 0.7547 - binary_accuracy: 0.7515 - val_loss: 0.6316 - val_auc: 0.6318 - val_binary_accuracy: 0.6912
# Epoch 38/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5289 - auc: 0.7366 - binary_accuracy: 0.7534
# Epoch 00038: val_auc did not improve from 0.69439
#
# Epoch 00038: val_loss did not improve from 0.58245
# 978/978 [==============================] - 38s 38ms/sample - loss: 0.5298 - auc: 0.7351 - binary_accuracy: 0.7533 - val_loss: 0.6564 - val_auc: 0.6123 - val_binary_accuracy: 0.6884
# Epoch 39/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5445 - auc: 0.7209 - binary_accuracy: 0.7464
# Epoch 00039: val_auc did not improve from 0.69439
#
# Epoch 00039: val_loss did not improve from 0.58245
# 978/978 [==============================] - 35s 36ms/sample - loss: 0.5437 - auc: 0.7223 - binary_accuracy: 0.7467 - val_loss: 0.6195 - val_auc: 0.6039 - val_binary_accuracy: 0.7183
# Epoch 40/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5287 - auc: 0.7403 - binary_accuracy: 0.7503
# Epoch 00040: val_auc did not improve from 0.69439
#
# Epoch 00040: val_loss did not improve from 0.58245
# 978/978 [==============================] - 26s 27ms/sample - loss: 0.5290 - auc: 0.7402 - binary_accuracy: 0.7505 - val_loss: 0.6177 - val_auc: 0.6689 - val_binary_accuracy: 0.6968
# Epoch 41/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5331 - auc: 0.7354 - binary_accuracy: 0.7518
# Epoch 00041: val_auc did not improve from 0.69439
#
# Epoch 00041: val_loss did not improve from 0.58245
# 978/978 [==============================] - 23s 23ms/sample - loss: 0.5333 - auc: 0.7350 - binary_accuracy: 0.7526 - val_loss: 0.6777 - val_auc: 0.5897 - val_binary_accuracy: 0.7108
# Epoch 42/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5248 - auc: 0.7518 - binary_accuracy: 0.7596
# Epoch 00042: val_auc did not improve from 0.69439
#
# Epoch 00042: val_loss did not improve from 0.58245
# 978/978 [==============================] - 26s 27ms/sample - loss: 0.5249 - auc: 0.7515 - binary_accuracy: 0.7592 - val_loss: 0.5953 - val_auc: 0.6369 - val_binary_accuracy: 0.7211
# Epoch 43/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5164 - auc: 0.7590 - binary_accuracy: 0.7555
# Epoch 00043: val_auc did not improve from 0.69439
#
# Epoch 00043: val_loss did not improve from 0.58245
# 978/978 [==============================] - 28s 29ms/sample - loss: 0.5156 - auc: 0.7596 - binary_accuracy: 0.7561 - val_loss: 0.6522 - val_auc: 0.5776 - val_binary_accuracy: 0.6679
# Epoch 44/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5190 - auc: 0.7579 - binary_accuracy: 0.7560
# Epoch 00044: val_auc did not improve from 0.69439
#
# Epoch 00044: val_loss did not improve from 0.58245
# 978/978 [==============================] - 28s 28ms/sample - loss: 0.5219 - auc: 0.7551 - binary_accuracy: 0.7551 - val_loss: 0.6087 - val_auc: 0.6368 - val_binary_accuracy: 0.7090
# Epoch 45/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5118 - auc: 0.7676 - binary_accuracy: 0.7628
# Epoch 00045: val_auc did not improve from 0.69439
#
# Epoch 00045: val_loss did not improve from 0.58245
# 978/978 [==============================] - 28s 29ms/sample - loss: 0.5139 - auc: 0.7647 - binary_accuracy: 0.7620 - val_loss: 0.5897 - val_auc: 0.6819 - val_binary_accuracy: 0.7239
# Epoch 46/50
# 960/978 [============================>.] - ETA: 0s - loss: 0.5064 - auc: 0.7766 - binary_accuracy: 0.7583
# Epoch 00046: val_auc did not improve from 0.69439
#
# Epoch 00046: val_loss did not improve from 0.58245
# 978/978 [==============================] - 28s 29ms/sample - loss: 0.5065 - auc: 0.7763 - binary_accuracy: 0.7587 - val_loss: 0.6306 - val_auc: 0.6182 - val_binary_accuracy: 0.7108
# 'y={"lb":labels["lb"],\n    "lm":labels["lm"],\n    "rm":labels["rm"],\n    "rb":labels["rb"]}\n    \n'

# %%
for i in history.history.keys():
  if "val" in i:
    continue
  # plot loss during training
  pyplot.subplot(211)
  pyplot.title(i)
  pyplot.plot(history.history[i], label='train')
  pyplot.plot(history.history['val_'+i], label='test')
  pyplot.show()

# %% [markdown]
# <h3 style="color:blue"> CROSS VAL 2/5 </h3>

# %%
col=["case","left_cc","left_mlo","right_cc","right_mlo","lb","lm","rb","rm"]
dtypes={"case": "str","left_cc": "str","left_mlo": "str","right_cc": "str","right_mlo": "str","lb": "int","lm": "int","rb": "int","rm": "int"}
df_training=pd.read_csv(directory+'/training_2.csv', sep=',', names=col,dtype=dtypes,  header=None)
df_validation=pd.read_csv(directory+'/validation_2.csv', sep=',', names=col,dtype=dtypes,  header=None)
#df_test=pd.read_csv(directory+'/test_r.csv', sep=',', names=col,dtype=dtypes,  header=None)

def read_spectograms(file_paths, img_rows, img_cols, channels):

  images = []
  
  for file_path in file_paths:
    if file_path=="nan":
        continue
    images.append(imread(file_path))
  
  images = np.asarray(images, dtype=np.float32)
  
  # normalize
  images = images / 255
  
  # reshape to match Keras expectaions
  images = images.reshape(images.shape[0], img_rows, img_cols, channels)

  return images


x_train_left_mlo = read_spectograms(df_training.left_mlo.values, img_rows, img_cols, in_channel)
x_train_left_cc= read_spectograms(df_training.left_cc.values, img_rows, img_cols, in_channel)

###Right

x_train_right_mlo = read_spectograms(df_training.right_mlo.values, img_rows, img_cols, in_channel)
x_train_right_cc= read_spectograms(df_training.right_cc.values, img_rows, img_cols, in_channel)

###labels

from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
labels = df_training[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels=labels.values
labels
print(type(labels))

x_validation_left_mlo = read_spectograms(df_validation.left_mlo.values, img_rows, img_cols, in_channel)
x_validation_left_cc= read_spectograms(df_validation.left_cc.values, img_rows, img_cols, in_channel)

x_validation_right_mlo = read_spectograms(df_validation.right_mlo.values, img_rows, img_cols, in_channel)
x_validation_right_cc= read_spectograms(df_validation.right_cc.values, img_rows, img_cols, in_channel)


mlb = MultiLabelBinarizer()
labels_validation = df_validation[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels_validation=labels_validation.values
labels_validation
print(type(labels_validation))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#  V 2

def resnetBlock(inputimage,k=2,striede=1, name=""):

  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(inputimage)


  activation=keras.activations.relu(batch_normalize )

  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(3,3),
    name="",
  padding="same"
  )(activation)

  conv1x1_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(1,1),
    name="",
#    activation=keras.activations.relu
  )(activation)


  batch_normalize_2 = keras.layers.BatchNormalization( axis=-1,name="")(conv3x3_1)

  activation2=keras.activations.relu(batch_normalize_2 )
  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    kernel_size=(3,3),
    name="",
    padding="same"
  )(activation2)

  outputs=keras.layers.Add()([conv3x3_1,conv1x1_1])
  return outputs


def resNetLayers(inputimage,name=""):
  block1=resnetBlock(inputimage,k=16,name="block1")
  #block2=resnetBlock(block1,k=16,name="block2")
  block3=resnetBlock(block1,k=16,striede=2,name="block3")
  #block4=resnetBlock(block3,k=32,name="block4")
  block5=resnetBlock(block3,k=32,striede=2,name="block5")
  pool=keras.layers.AveragePooling2D(
      pool_size=(3,3), strides=2, padding='same', name='' #(3,3)
  )(block5)
  #block6=resnetBlock(block5,k=32,striede=2,name="block6")
  block7=resnetBlock(pool,k=32,striede=2,name="block7")
  #block8=resnetBlock(inputfilter=128,k=128,name="block8")(block7)
  
  #block10=resnetBlock(inputfilter=256,k=256,name="block10")(block9)
  return block7

def singleViewResnet(inputimage, name=""):

  conv7x7=tf.keras.layers.Conv2D(
    filters=16,
    strides=2,
    kernel_size=(5,5),
    name="",
    activation=keras.activations.relu
  )(inputimage)

  pool3x3=keras.layers.AveragePooling2D(
      pool_size=(2,2), strides=2, padding='same', name='' #(3,3)
  )(conv7x7)

  resNetL=resNetLayers(pool3x3,name="")
  print(resNetL.shape)
  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(resNetL)

  relu=keras.activations.relu(batch_normalize)
  
  return relu


def view_wise(img_rows=300, img_cols=300):
  left_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_cc")
  right_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_cc"
  )  

  left_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_mlo"
  )  
  right_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_mlo"
  )

  #cc_resnet=singleViewResnet(name="cc_resnet")
  #mlo_resnet=singleViewResnet(name="mlo_resnet")

  cc_resnet_left=singleViewResnet(left_cc_input)
  cc_resnet_right=singleViewResnet(right_cc_input)

  mlo_resnet_left=singleViewResnet(left_mlo_input)
  mlo_resent_right=singleViewResnet(right_mlo_input)

  avg_pool_cc_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_left)
  avg_pool_cc_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_right)

  avg_pool_mlo_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resnet_left)
  avg_pool_mlo_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resent_right)

  mlo=keras.layers.Concatenate(axis=-1)([avg_pool_mlo_left, avg_pool_mlo_right])
  cc=keras.layers.Concatenate(axis=-1)([avg_pool_cc_left, avg_pool_cc_right])

  mlo_flatten=tf.keras.layers.Flatten()(mlo)
  cc_flatten=tf.keras.layers.Flatten()(cc)

  """
  mlo_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(256,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(mlo_flatten)
    )
  """
  mlo_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_flatten)
        )
      )
  mlo_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_dense1)
        )
      ) 
  
  mlo_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(mlo_dense3)
    )
  
  """
  cc_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(512,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(cc_flatten)
    )
  """
  

  cc_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_flatten)
        )
      )
  cc_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_dense1)
        )
      ) 
 
  cc_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(cc_dense3)
    )
  
  
  
  """mlo_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rb")(mlo_dense2)
  mlo_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rm")(mlo_dense2)
  mlo_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lb")(mlo_dense2)
  mlo_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lm")(mlo_dense2)
  
  cc_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rb")(cc_dense2)
  cc_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rm")(cc_dense2)
  cc_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lb")(cc_dense2)
  cc_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lm")(cc_dense2)
  
  rb_output = keras.layers.Average(name="rb")([mlo_rb,cc_rb])
  rm_output = keras.layers.Average(name="rm")([mlo_rm,cc_rm])
  lb_output = keras.layers.Average(name="lb")([mlo_lb,cc_lb])
  lm_output = keras.layers.Average(name="lm")([mlo_lm,cc_lm])"""

  output=keras.layers.Average(name="outpu")([cc_dense2,mlo_dense2])

  output=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(output)
    )
  
 
  output=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(4,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(output)
    )

  return keras.Model(
      inputs=[left_cc_input, right_cc_input, left_mlo_input, right_mlo_input],
      outputs=output,name="view-wise"
  )
model=view_wise(img_rows, img_cols)
#model.summary()
#keras.utils.plot_model(model, "/gdrive/My Drive/Colab_Notebooks/NNPROJECT/image_Net/view-wise.png", show_shapes=True, expand_nested=False)
# Out:
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)

# %%
batch_size=32
step_per_epoch=len(x_train_left_mlo)/batch_size

cbks = [tf.keras.callbacks.EarlyStopping(patience=10, monitor="val_loss"),
        tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_auc2",
                    monitor="val_auc",
                    mode="max",
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
                    
        ),
       tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_loss2",
                    monitor="val_loss",
                    
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
       )]

model.compile(#optimizer=keras.optimizers.Adam(lr=0.001),
              #optimizer=keras.optimizers.SGD(lr=0.0005, decay=1e-6, momentum=0.9, nesterov=True),
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005,rho=0.9,momentum=0.9,epsilon=1e-07),
              loss=keras.losses.BinaryCrossentropy(),
              callbacks = cbks,
              #loss=custom_loss,
              metrics=[tf.keras.metrics.AUC(name="auc"),tf.keras.metrics.BinaryAccuracy(threshold=0.5)]#tf.keras.metrics.BinaryAccuracy(threshold=0.01)]#,
             )

history=model.fit(x={"left_mlo": x_train_left_mlo,
                         "left_cc": x_train_left_cc,
                         "right_mlo":x_train_right_mlo,
                         "right_cc":x_train_right_cc},
                  y=labels.values,
                  epochs=30,verbose=1,

                  validation_data=(
                      {"left_mlo": x_validation_left_mlo,
                         "left_cc": x_validation_left_cc,
                         "right_mlo":x_validation_right_mlo,
                         "right_cc":x_validation_right_cc},
                    labels_validation.values
                  ))

"""y={"lb":labels["lb"],
    "lm":labels["lm"],
    "rm":labels["rm"],
    "rb":labels["rb"]}
    
"""
# Out:
# Train on 1009 samples, validate on 237 samples
# Epoch 1/30
# 1009/1009 [==============================] - 62s 62ms/sample - loss: 1.1172 - auc: 0.5117 - binary_accuracy: 0.7054 - val_loss: 1.0344 - val_auc: 0.5138 - val_binary_accuracy: 0.7426
# Epoch 2/30
# 1009/1009 [==============================] - 28s 27ms/sample - loss: 1.0128 - auc: 0.4958 - binary_accuracy: 0.7317 - val_loss: 0.9460 - val_auc: 0.5682 - val_binary_accuracy: 0.7426
# Epoch 3/30
# 1009/1009 [==============================] - 25s 24ms/sample - loss: 0.9319 - auc: 0.5036 - binary_accuracy: 0.7319 - val_loss: 0.8804 - val_auc: 0.5055 - val_binary_accuracy: 0.7426
# Epoch 4/30
# 1009/1009 [==============================] - 22s 22ms/sample - loss: 0.8654 - auc: 0.5104 - binary_accuracy: 0.7319 - val_loss: 0.8200 - val_auc: 0.5149 - val_binary_accuracy: 0.7426
# Epoch 5/30
# 1009/1009 [==============================] - 22s 21ms/sample - loss: 0.8146 - auc: 0.5007 - binary_accuracy: 0.7322 - val_loss: 0.7747 - val_auc: 0.5046 - val_binary_accuracy: 0.7426
# Epoch 6/30
# 1009/1009 [==============================] - 21s 21ms/sample - loss: 0.7689 - auc: 0.5171 - binary_accuracy: 0.7319 - val_loss: 0.7342 - val_auc: 0.5437 - val_binary_accuracy: 0.7426
# Epoch 7/30
# 1009/1009 [==============================] - 20s 20ms/sample - loss: 0.7353 - auc: 0.5140 - binary_accuracy: 0.7319 - val_loss: 0.7082 - val_auc: 0.5277 - val_binary_accuracy: 0.7426
# Epoch 8/30
# 1009/1009 [==============================] - 28s 28ms/sample - loss: 0.7000 - auc: 0.5581 - binary_accuracy: 0.7319 - val_loss: 0.6599 - val_auc: 0.7087 - val_binary_accuracy: 0.7426
# Epoch 9/30
# 1009/1009 [==============================] - 20s 20ms/sample - loss: 0.6666 - auc: 0.6143 - binary_accuracy: 0.7307 - val_loss: 0.6450 - val_auc: 0.6412 - val_binary_accuracy: 0.7426
# Epoch 10/30
# 1009/1009 [==============================] - 25s 25ms/sample - loss: 0.6470 - auc: 0.6233 - binary_accuracy: 0.7299 - val_loss: 0.6510 - val_auc: 0.5088 - val_binary_accuracy: 0.7426
# Epoch 11/30
# 1009/1009 [==============================] - 18s 18ms/sample - loss: 0.6316 - auc: 0.6161 - binary_accuracy: 0.7324 - val_loss: 0.6696 - val_auc: 0.5000 - val_binary_accuracy: 0.7289
# Epoch 12/30
# 1009/1009 [==============================] - 22s 22ms/sample - loss: 0.6100 - auc: 0.6448 - binary_accuracy: 0.7327 - val_loss: 0.6456 - val_auc: 0.4191 - val_binary_accuracy: 0.7426
# Epoch 13/30
# 1009/1009 [==============================] - 21s 21ms/sample - loss: 0.6097 - auc: 0.6355 - binary_accuracy: 0.7309 - val_loss: 0.6508 - val_auc: 0.5521 - val_binary_accuracy: 0.7395
# Epoch 14/30
# 1009/1009 [==============================] - 20s 19ms/sample - loss: 0.5986 - auc: 0.6389 - binary_accuracy: 0.7344 - val_loss: 0.5994 - val_auc: 0.6034 - val_binary_accuracy: 0.7426
# Epoch 15/30
# 1009/1009 [==============================] - 19s 19ms/sample - loss: 0.5873 - auc: 0.6453 - binary_accuracy: 0.7364 - val_loss: 0.6191 - val_auc: 0.4346 - val_binary_accuracy: 0.7405
# Epoch 16/30
# 1009/1009 [==============================] - 18s 18ms/sample - loss: 0.5871 - auc: 0.6377 - binary_accuracy: 0.7346 - val_loss: 0.6461 - val_auc: 0.6035 - val_binary_accuracy: 0.7215
# Epoch 17/30
# 1009/1009 [==============================] - 19s 19ms/sample - loss: 0.5739 - auc: 0.6558 - binary_accuracy: 0.7376 - val_loss: 0.5918 - val_auc: 0.5533 - val_binary_accuracy: 0.7447
# Epoch 18/30
# 1009/1009 [==============================] - 15s 15ms/sample - loss: 0.5747 - auc: 0.6577 - binary_accuracy: 0.7354 - val_loss: 0.5914 - val_auc: 0.5509 - val_binary_accuracy: 0.7426
# Epoch 19/30
# 1009/1009 [==============================] - 18s 18ms/sample - loss: 0.5716 - auc: 0.6517 - binary_accuracy: 0.7339 - val_loss: 0.5995 - val_auc: 0.6024 - val_binary_accuracy: 0.7447
# Epoch 20/30
# 1009/1009 [==============================] - 16s 16ms/sample - loss: 0.5688 - auc: 0.6487 - binary_accuracy: 0.7359 - val_loss: 0.7020 - val_auc: 0.5848 - val_binary_accuracy: 0.7089
# Epoch 21/30
# 1009/1009 [==============================] - 16s 16ms/sample - loss: 0.5590 - auc: 0.6727 - binary_accuracy: 0.7369 - val_loss: 0.6553 - val_auc: 0.5865 - val_binary_accuracy: 0.7205
# Epoch 22/30
# 1009/1009 [==============================] - 15s 15ms/sample - loss: 0.5562 - auc: 0.6766 - binary_accuracy: 0.7344 - val_loss: 0.5974 - val_auc: 0.5157 - val_binary_accuracy: 0.7426
# Epoch 23/30
# 1009/1009 [==============================] - 37s 36ms/sample - loss: 0.5564 - auc: 0.6738 - binary_accuracy: 0.7364 - val_loss: 0.5800 - val_auc: 0.6011 - val_binary_accuracy: 0.7405
# Epoch 24/30
# 1009/1009 [==============================] - 26s 26ms/sample - loss: 0.5543 - auc: 0.6770 - binary_accuracy: 0.7374 - val_loss: 0.5719 - val_auc: 0.6435 - val_binary_accuracy: 0.7416
# Epoch 25/30
# 1009/1009 [==============================] - 19s 19ms/sample - loss: 0.5590 - auc: 0.6600 - binary_accuracy: 0.7356 - val_loss: 0.5753 - val_auc: 0.5649 - val_binary_accuracy: 0.7416
# Epoch 26/30
# 1009/1009 [==============================] - 22s 21ms/sample - loss: 0.5461 - auc: 0.6854 - binary_accuracy: 0.7386 - val_loss: 0.5787 - val_auc: 0.6245 - val_binary_accuracy: 0.7363
# Epoch 27/30
# 1009/1009 [==============================] - 28s 28ms/sample - loss: 0.5462 - auc: 0.6894 - binary_accuracy: 0.7386 - val_loss: 0.5787 - val_auc: 0.6102 - val_binary_accuracy: 0.7426
# Epoch 28/30
# 1009/1009 [==============================] - 29s 29ms/sample - loss: 0.5438 - auc: 0.6938 - binary_accuracy: 0.7406 - val_loss: 0.5801 - val_auc: 0.5834 - val_binary_accuracy: 0.7447
# Epoch 29/30
# 1009/1009 [==============================] - 22s 22ms/sample - loss: 0.5435 - auc: 0.6974 - binary_accuracy: 0.7376 - val_loss: 0.5875 - val_auc: 0.6044 - val_binary_accuracy: 0.7342
# Epoch 30/30
# 1009/1009 [==============================] - 23s 23ms/sample - loss: 0.5410 - auc: 0.7017 - binary_accuracy: 0.7408 - val_loss: 0.5662 - val_auc: 0.6531 - val_binary_accuracy: 0.7395
# 'y={"lb":labels["lb"],\n    "lm":labels["lm"],\n    "rm":labels["rm"],\n    "rb":labels["rb"]}\n    \n'

# %%
for i in history.history.keys():
  if "val" in i:
    continue
  # plot loss during training
  pyplot.subplot(211)
  pyplot.title(i)
  pyplot.plot(history.history[i], label='train')
  pyplot.plot(history.history['val_'+i], label='test')
  pyplot.show()

# %% [markdown]
# <h3 style="color:blue"> CROSS VAL 3/5 </h3>

# %%
col=["case","left_cc","left_mlo","right_cc","right_mlo","lb","lm","rb","rm"]
dtypes={"case": "str","left_cc": "str","left_mlo": "str","right_cc": "str","right_mlo": "str","lb": "int","lm": "int","rb": "int","rm": "int"}
df_training=pd.read_csv(directory+'/training_3.csv', sep=',', names=col,dtype=dtypes,  header=None)
df_validation=pd.read_csv(directory+'/validation_3.csv', sep=',', names=col,dtype=dtypes,  header=None)
#df_test=pd.read_csv(directory+'/test_r.csv', sep=',', names=col,dtype=dtypes,  header=None)

def read_spectograms(file_paths, img_rows, img_cols, channels):

  images = []
  
  for file_path in file_paths:
    if file_path=="nan":
        continue
    images.append(imread(file_path))
  
  images = np.asarray(images, dtype=np.float32)
  
  # normalize
  images = images / 255
  
  # reshape to match Keras expectaions
  images = images.reshape(images.shape[0], img_rows, img_cols, channels)

  return images


x_train_left_mlo = read_spectograms(df_training.left_mlo.values, img_rows, img_cols, in_channel)
x_train_left_cc= read_spectograms(df_training.left_cc.values, img_rows, img_cols, in_channel)

###Right

x_train_right_mlo = read_spectograms(df_training.right_mlo.values, img_rows, img_cols, in_channel)
x_train_right_cc= read_spectograms(df_training.right_cc.values, img_rows, img_cols, in_channel)

###labels

from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
labels = df_training[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels=labels.values
labels
print(type(labels))

x_validation_left_mlo = read_spectograms(df_validation.left_mlo.values, img_rows, img_cols, in_channel)
x_validation_left_cc= read_spectograms(df_validation.left_cc.values, img_rows, img_cols, in_channel)

x_validation_right_mlo = read_spectograms(df_validation.right_mlo.values, img_rows, img_cols, in_channel)
x_validation_right_cc= read_spectograms(df_validation.right_cc.values, img_rows, img_cols, in_channel)


mlb = MultiLabelBinarizer()
labels_validation = df_validation[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels_validation=labels_validation.values
labels_validation
print(type(labels_validation))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#  V 2

def resnetBlock(inputimage,k=2,striede=1, name=""):

  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(inputimage)


  activation=keras.activations.relu(batch_normalize )

  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(3,3),
    name="",
  padding="same"
  )(activation)

  conv1x1_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(1,1),
    name="",
#    activation=keras.activations.relu
  )(activation)


  batch_normalize_2 = keras.layers.BatchNormalization( axis=-1,name="")(conv3x3_1)

  activation2=keras.activations.relu(batch_normalize_2 )
  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    kernel_size=(3,3),
    name="",
    padding="same"
  )(activation2)

  outputs=keras.layers.Add()([conv3x3_1,conv1x1_1])
  return outputs


def resNetLayers(inputimage,name=""):
  block1=resnetBlock(inputimage,k=16,name="block1")
  #block2=resnetBlock(block1,k=16,name="block2")
  block3=resnetBlock(block1,k=16,striede=2,name="block3")
  #block4=resnetBlock(block3,k=32,name="block4")
  block5=resnetBlock(block3,k=32,striede=2,name="block5")
  pool=keras.layers.AveragePooling2D(
      pool_size=(3,3), strides=2, padding='same', name='' #(3,3)
  )(block5)
  #block6=resnetBlock(block5,k=32,striede=2,name="block6")
  block7=resnetBlock(pool,k=32,striede=2,name="block7")
  #block8=resnetBlock(inputfilter=128,k=128,name="block8")(block7)
  
  #block10=resnetBlock(inputfilter=256,k=256,name="block10")(block9)
  return block7

def singleViewResnet(inputimage, name=""):

  conv7x7=tf.keras.layers.Conv2D(
    filters=16,
    strides=2,
    kernel_size=(5,5),
    name="",
    activation=keras.activations.relu
  )(inputimage)

  pool3x3=keras.layers.AveragePooling2D(
      pool_size=(2,2), strides=2, padding='same', name='' #(3,3)
  )(conv7x7)

  resNetL=resNetLayers(pool3x3,name="")
  print(resNetL.shape)
  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(resNetL)

  relu=keras.activations.relu(batch_normalize)
  
  return relu


def view_wise(img_rows=300, img_cols=300):
  left_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_cc")
  right_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_cc"
  )  

  left_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_mlo"
  )  
  right_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_mlo"
  )

  #cc_resnet=singleViewResnet(name="cc_resnet")
  #mlo_resnet=singleViewResnet(name="mlo_resnet")

  cc_resnet_left=singleViewResnet(left_cc_input)
  cc_resnet_right=singleViewResnet(right_cc_input)

  mlo_resnet_left=singleViewResnet(left_mlo_input)
  mlo_resent_right=singleViewResnet(right_mlo_input)

  avg_pool_cc_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_left)
  avg_pool_cc_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_right)

  avg_pool_mlo_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resnet_left)
  avg_pool_mlo_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resent_right)

  mlo=keras.layers.Concatenate(axis=-1)([avg_pool_mlo_left, avg_pool_mlo_right])
  cc=keras.layers.Concatenate(axis=-1)([avg_pool_cc_left, avg_pool_cc_right])

  mlo_flatten=tf.keras.layers.Flatten()(mlo)
  cc_flatten=tf.keras.layers.Flatten()(cc)

  """
  mlo_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(256,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(mlo_flatten)
    )
  """
  mlo_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_flatten)
        )
      )
  mlo_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_dense1)
        )
      ) 
  
  mlo_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(mlo_dense3)
    )
  
  """
  cc_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(512,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(cc_flatten)
    )
  """
  

  cc_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_flatten)
        )
      )
  cc_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_dense1)
        )
      ) 
 
  cc_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(cc_dense3)
    )
  
  
  
  """mlo_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rb")(mlo_dense2)
  mlo_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rm")(mlo_dense2)
  mlo_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lb")(mlo_dense2)
  mlo_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lm")(mlo_dense2)
  
  cc_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rb")(cc_dense2)
  cc_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rm")(cc_dense2)
  cc_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lb")(cc_dense2)
  cc_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lm")(cc_dense2)
  
  rb_output = keras.layers.Average(name="rb")([mlo_rb,cc_rb])
  rm_output = keras.layers.Average(name="rm")([mlo_rm,cc_rm])
  lb_output = keras.layers.Average(name="lb")([mlo_lb,cc_lb])
  lm_output = keras.layers.Average(name="lm")([mlo_lm,cc_lm])"""

  output=keras.layers.Average(name="outpu")([cc_dense2,mlo_dense2])

  output=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(output)
    )
  
 
  output=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(4,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(output)
    )

  return keras.Model(
      inputs=[left_cc_input, right_cc_input, left_mlo_input, right_mlo_input],
      outputs=output,name="view-wise"
  )
model=view_wise(img_rows, img_cols)
model.summary()
#keras.utils.plot_model(model, "/gdrive/My Drive/Colab_Notebooks/NNPROJECT/image_Net/view-wise.png", show_shapes=True, expand_nested=False)
# Out:
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# Model: "view-wise"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_cc (InputLayer)            [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# right_cc (InputLayer)           [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# left_mlo (InputLayer)           [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# right_mlo (InputLayer)          [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 254, 190, 16) 1216        left_cc[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 254, 190, 16) 1216        right_cc[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 254, 190, 16) 1216        left_mlo[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 254, 190, 16) 1216        right_mlo[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 127, 95, 16)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 127, 95, 16)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 127, 95, 16)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 127, 95, 16)  0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 127, 95, 16)  64          average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 127, 95, 16)  64          average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 127, 95, 16)  64          average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 127, 95, 16)  64          average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu (TensorFlowOpL [(None, 127, 95, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_9 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_18 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_27 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 127, 95, 16)  2320        tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 127, 95, 16)  64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 127, 95, 16)  64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 127, 95, 16)  64          conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 127, 95, 16)  64          conv2d_40[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_1 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_10 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_19 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_28 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 127, 95, 16)  2320        tf_op_layer_Relu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 127, 95, 16)  272         tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_28[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_27[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 127, 95, 16)  0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 127, 95, 16)  0           conv2d_16[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 127, 95, 16)  0           conv2d_29[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 127, 95, 16)  0           conv2d_42[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 127, 95, 16)  64          add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 127, 95, 16)  64          add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 127, 95, 16)  64          add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 127, 95, 16)  64          add_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_2 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_11 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_20 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_29 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 48, 16)   2320        tf_op_layer_Relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 48, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 48, 16)   64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 48, 16)   64          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 48, 16)   64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_3 (TensorFlowO [(None, 64, 48, 16)] 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_12 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_21 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_30 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 48, 16)   2320        tf_op_layer_Relu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 48, 16)   272         tf_op_layer_Relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_30[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 48, 16)   0           conv2d_6[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 48, 16)   0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 48, 16)   0           conv2d_32[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 48, 16)   0           conv2d_45[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 48, 16)   64          add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 48, 16)   64          add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 48, 16)   64          add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 48, 16)   64          add_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_4 (TensorFlowO [(None, 64, 48, 16)] 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_13 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_22 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_31 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 24, 32)   4640        tf_op_layer_Relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 24, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 24, 32)   128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 24, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 24, 32)   128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_5 (TensorFlowO [(None, 32, 24, 32)] 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_14 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_23 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_32 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 24, 32)   9248        tf_op_layer_Relu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 24, 32)   544         tf_op_layer_Relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_32[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_31[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 24, 32)   0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 24, 32)   0           conv2d_22[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 24, 32)   0           conv2d_35[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 24, 32)   0           conv2d_48[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 16, 12, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 16, 12, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 16, 12, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 16, 12, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 12, 32)   128         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_6 (TensorFlowO [(None, 16, 12, 32)] 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_15 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_24 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_33 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 6, 32)     128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 6, 32)     128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 6, 32)     128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 6, 32)     128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_7 (TensorFlowO [(None, 8, 6, 32)]   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_16 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_25 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_34 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_34[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_33[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 6, 32)     0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 6, 32)     0           conv2d_25[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 6, 32)     0           conv2d_38[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 6, 32)     0           conv2d_51[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 6, 32)     128         add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 6, 32)     128         add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 6, 32)     128         add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 6, 32)     128         add_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_8 (TensorFlowO [(None, 8, 6, 32)]   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_17 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_26 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_35 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 4, 3, 32)     0           tf_op_layer_Relu_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 4, 3, 32)     0           tf_op_layer_Relu_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 4, 3, 32)     0           tf_op_layer_Relu_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 4, 3, 32)     0           tf_op_layer_Relu_35[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 3, 64)     0           average_pooling2d_8[0][0]
#                                                                  average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 3, 64)     0           average_pooling2d_10[0][0]
#                                                                  average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 768)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 768)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2048)         1574912     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         1574912     flatten[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 2048)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 2048)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2048)         0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024)         2098176     dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     dropout[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 1024)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           65600       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           65600       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# outpu (Average)                 (None, 64)           0           dropout_5[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           4160        outpu[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 4)            260         dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 4)            0           dense_7[0][0]
# ==================================================================================================
# Total params: 7,665,220
# Trainable params: 7,663,556
# Non-trainable params: 1,664
# __________________________________________________________________________________________________

# %%
batch_size=32
step_per_epoch=len(x_train_left_mlo)/batch_size

cbks = [tf.keras.callbacks.EarlyStopping(patience=10, monitor="val_loss"),
        tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_auc3",
                    monitor="val_auc",
                    mode="max",
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
                    
        ),
       tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_loss3",
                    monitor="val_loss",
                    
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
       )]


model.compile(#optimizer=keras.optimizers.Adam(lr=0.001),
              #optimizer=keras.optimizers.SGD(lr=0.0005, decay=1e-6, momentum=0.9, nesterov=True),
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005,rho=0.9,momentum=0.9,epsilon=1e-07),
              loss=keras.losses.BinaryCrossentropy(),
              #loss=custom_loss,
              metrics=[tf.keras.metrics.AUC(name="auc"),tf.keras.metrics.BinaryAccuracy(threshold=0.5)]#tf.keras.metrics.BinaryAccuracy(threshold=0.01)]#,
             )



history=model.fit(x={"left_mlo": x_train_left_mlo,
                         "left_cc": x_train_left_cc,
                         "right_mlo":x_train_right_mlo,
                         "right_cc":x_train_right_cc},
                  y=labels.values,
                  epochs=50,verbose=1,
                  callbacks=cbks,
                  validation_data=(
                      {"left_mlo": x_validation_left_mlo,
                         "left_cc": x_validation_left_cc,
                         "right_mlo":x_validation_right_mlo,
                         "right_cc":x_validation_right_cc},
                    labels_validation.values
                  ))

"""y={"lb":labels["lb"],
    "lm":labels["lm"],
    "rm":labels["rm"],
    "rb":labels["rb"]}
    
"""
# Out:
# Train on 964 samples, validate on 282 samples
# Epoch 1/50
# 960/964 [============================>.] - ETA: 0s - loss: 1.1149 - auc: 0.4997 - binary_accuracy: 0.7102
# Epoch 00001: val_auc improved from -inf to 0.45274, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3
# WARNING:tensorflow:From c:\users\lpatr\.virtualenvs\proj-r1r8_6rp\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3\assets
#
# Epoch 00001: val_loss improved from inf to 1.05047, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 87s 90ms/sample - loss: 1.1146 - auc: 0.4996 - binary_accuracy: 0.7103 - val_loss: 1.0505 - val_auc: 0.4527 - val_binary_accuracy: 0.7323
# Epoch 2/50
# 960/964 [============================>.] - ETA: 0s - loss: 1.0115 - auc: 0.5166 - binary_accuracy: 0.7341
# Epoch 00002: val_auc improved from 0.45274 to 0.48070, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3\assets
#
# Epoch 00002: val_loss improved from 1.05047 to 0.96711, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 77s 80ms/sample - loss: 1.0113 - auc: 0.5166 - binary_accuracy: 0.7342 - val_loss: 0.9671 - val_auc: 0.4807 - val_binary_accuracy: 0.7323
# Epoch 3/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.9346 - auc: 0.5172 - binary_accuracy: 0.7339
# Epoch 00003: val_auc improved from 0.48070 to 0.54760, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3\assets
#
# Epoch 00003: val_loss improved from 0.96711 to 0.89427, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 111s 115ms/sample - loss: 0.9343 - auc: 0.5175 - binary_accuracy: 0.7339 - val_loss: 0.8943 - val_auc: 0.5476 - val_binary_accuracy: 0.7323
# Epoch 4/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.8657 - auc: 0.5429 - binary_accuracy: 0.7346
# Epoch 00004: val_auc did not improve from 0.54760
#
# Epoch 00004: val_loss improved from 0.89427 to 0.83921, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 63s 65ms/sample - loss: 0.8653 - auc: 0.5438 - binary_accuracy: 0.7347 - val_loss: 0.8392 - val_auc: 0.5101 - val_binary_accuracy: 0.7323
# Epoch 5/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.8061 - auc: 0.5792 - binary_accuracy: 0.7333
# Epoch 00005: val_auc did not improve from 0.54760
#
# Epoch 00005: val_loss improved from 0.83921 to 0.81807, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 66s 69ms/sample - loss: 0.8060 - auc: 0.5792 - binary_accuracy: 0.7337 - val_loss: 0.8181 - val_auc: 0.4505 - val_binary_accuracy: 0.7323
# Epoch 6/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.7636 - auc: 0.5919 - binary_accuracy: 0.7331
# Epoch 00006: val_auc did not improve from 0.54760
#
# Epoch 00006: val_loss improved from 0.81807 to 0.75470, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 57s 59ms/sample - loss: 0.7636 - auc: 0.5915 - binary_accuracy: 0.7331 - val_loss: 0.7547 - val_auc: 0.5252 - val_binary_accuracy: 0.7323
# Epoch 7/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.7268 - auc: 0.5957 - binary_accuracy: 0.7344
# Epoch 00007: val_auc improved from 0.54760 to 0.60046, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3\assets
#
# Epoch 00007: val_loss improved from 0.75470 to 0.71416, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 97s 101ms/sample - loss: 0.7271 - auc: 0.5947 - binary_accuracy: 0.7344 - val_loss: 0.7142 - val_auc: 0.6005 - val_binary_accuracy: 0.7323
# Epoch 8/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.6958 - auc: 0.6093 - binary_accuracy: 0.7333
# Epoch 00008: val_auc did not improve from 0.60046
#
# Epoch 00008: val_loss improved from 0.71416 to 0.69998, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 93s 97ms/sample - loss: 0.6957 - auc: 0.6092 - binary_accuracy: 0.7334 - val_loss: 0.7000 - val_auc: 0.5709 - val_binary_accuracy: 0.7323
# Epoch 9/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.6707 - auc: 0.6252 - binary_accuracy: 0.7312
# Epoch 00009: val_auc improved from 0.60046 to 0.63876, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc3\assets
#
# Epoch 00009: val_loss improved from 0.69998 to 0.65619, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 102s 105ms/sample - loss: 0.6704 - auc: 0.6258 - binary_accuracy: 0.7313 - val_loss: 0.6562 - val_auc: 0.6388 - val_binary_accuracy: 0.7323
# Epoch 10/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.6469 - auc: 0.6365 - binary_accuracy: 0.7344
# Epoch 00010: val_auc did not improve from 0.63876
#
# Epoch 00010: val_loss did not improve from 0.65619
# 964/964 [==============================] - 39s 41ms/sample - loss: 0.6471 - auc: 0.6358 - binary_accuracy: 0.7344 - val_loss: 0.6733 - val_auc: 0.5043 - val_binary_accuracy: 0.7323
# Epoch 11/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.6239 - auc: 0.6558 - binary_accuracy: 0.7362
# Epoch 00011: val_auc did not improve from 0.63876
#
# Epoch 00011: val_loss did not improve from 0.65619
# 964/964 [==============================] - 29s 31ms/sample - loss: 0.6239 - auc: 0.6556 - binary_accuracy: 0.7363 - val_loss: 0.6770 - val_auc: 0.5030 - val_binary_accuracy: 0.7216
# Epoch 12/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.6168 - auc: 0.6493 - binary_accuracy: 0.7344
# Epoch 00012: val_auc did not improve from 0.63876
#
# Epoch 00012: val_loss did not improve from 0.65619
# 964/964 [==============================] - 29s 30ms/sample - loss: 0.6169 - auc: 0.6488 - binary_accuracy: 0.7344 - val_loss: 0.7269 - val_auc: 0.5112 - val_binary_accuracy: 0.6915
# Epoch 13/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.6078 - auc: 0.6466 - binary_accuracy: 0.7328
# Epoch 00013: val_auc did not improve from 0.63876
#
# Epoch 00013: val_loss did not improve from 0.65619
# 964/964 [==============================] - 27s 28ms/sample - loss: 0.6076 - auc: 0.6469 - binary_accuracy: 0.7329 - val_loss: 0.6830 - val_auc: 0.4759 - val_binary_accuracy: 0.7332
# Epoch 14/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5908 - auc: 0.6644 - binary_accuracy: 0.7357
# Epoch 00014: val_auc did not improve from 0.63876
#
# Epoch 00014: val_loss improved from 0.65619 to 0.65606, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 62s 64ms/sample - loss: 0.5909 - auc: 0.6640 - binary_accuracy: 0.7357 - val_loss: 0.6561 - val_auc: 0.5266 - val_binary_accuracy: 0.7332
# Epoch 15/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5821 - auc: 0.6708 - binary_accuracy: 0.7344
# Epoch 00015: val_auc did not improve from 0.63876
#
# Epoch 00015: val_loss did not improve from 0.65606
# 964/964 [==============================] - 37s 39ms/sample - loss: 0.5830 - auc: 0.6687 - binary_accuracy: 0.7342 - val_loss: 0.6562 - val_auc: 0.5122 - val_binary_accuracy: 0.7323
# Epoch 16/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5860 - auc: 0.6397 - binary_accuracy: 0.7393
# Epoch 00016: val_auc did not improve from 0.63876
#
# Epoch 00016: val_loss improved from 0.65606 to 0.63861, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 78s 81ms/sample - loss: 0.5863 - auc: 0.6389 - binary_accuracy: 0.7394 - val_loss: 0.6386 - val_auc: 0.5555 - val_binary_accuracy: 0.7314
# Epoch 17/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5776 - auc: 0.6571 - binary_accuracy: 0.7372
# Epoch 00017: val_auc did not improve from 0.63876
#
# Epoch 00017: val_loss improved from 0.63861 to 0.61706, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 86s 90ms/sample - loss: 0.5776 - auc: 0.6570 - binary_accuracy: 0.7370 - val_loss: 0.6171 - val_auc: 0.5514 - val_binary_accuracy: 0.7323
# Epoch 18/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5664 - auc: 0.6752 - binary_accuracy: 0.7375
# Epoch 00018: val_auc did not improve from 0.63876
#
# Epoch 00018: val_loss did not improve from 0.61706
# 964/964 [==============================] - 29s 30ms/sample - loss: 0.5672 - auc: 0.6741 - binary_accuracy: 0.7373 - val_loss: 0.6566 - val_auc: 0.5031 - val_binary_accuracy: 0.7323
# Epoch 19/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5572 - auc: 0.6921 - binary_accuracy: 0.7352
# Epoch 00019: val_auc did not improve from 0.63876
#
# Epoch 00019: val_loss did not improve from 0.61706
# 964/964 [==============================] - 23s 23ms/sample - loss: 0.5567 - auc: 0.6929 - binary_accuracy: 0.7352 - val_loss: 0.7247 - val_auc: 0.4824 - val_binary_accuracy: 0.7323
# Epoch 20/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5594 - auc: 0.6845 - binary_accuracy: 0.7378
# Epoch 00020: val_auc did not improve from 0.63876
#
# Epoch 00020: val_loss did not improve from 0.61706
# 964/964 [==============================] - 16s 17ms/sample - loss: 0.5595 - auc: 0.6845 - binary_accuracy: 0.7376 - val_loss: 0.6305 - val_auc: 0.5836 - val_binary_accuracy: 0.7057
# Epoch 21/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5500 - auc: 0.6981 - binary_accuracy: 0.7362
# Epoch 00021: val_auc did not improve from 0.63876
#
# Epoch 00021: val_loss did not improve from 0.61706
# 964/964 [==============================] - 21s 22ms/sample - loss: 0.5496 - auc: 0.6987 - binary_accuracy: 0.7365 - val_loss: 0.6627 - val_auc: 0.5448 - val_binary_accuracy: 0.7004
# Epoch 22/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5480 - auc: 0.6973 - binary_accuracy: 0.7380
# Epoch 00022: val_auc did not improve from 0.63876
#
# Epoch 00022: val_loss improved from 0.61706 to 0.58447, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss3\assets
# 964/964 [==============================] - 61s 64ms/sample - loss: 0.5479 - auc: 0.6973 - binary_accuracy: 0.7381 - val_loss: 0.5845 - val_auc: 0.6239 - val_binary_accuracy: 0.7296
# Epoch 23/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5470 - auc: 0.6985 - binary_accuracy: 0.7396
# Epoch 00023: val_auc did not improve from 0.63876
#
# Epoch 00023: val_loss did not improve from 0.58447
# 964/964 [==============================] - 36s 38ms/sample - loss: 0.5475 - auc: 0.6979 - binary_accuracy: 0.7391 - val_loss: 0.6612 - val_auc: 0.5202 - val_binary_accuracy: 0.7048
# Epoch 24/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5431 - auc: 0.7050 - binary_accuracy: 0.7388
# Epoch 00024: val_auc did not improve from 0.63876
#
# Epoch 00024: val_loss did not improve from 0.58447
# 964/964 [==============================] - 18s 18ms/sample - loss: 0.5427 - auc: 0.7062 - binary_accuracy: 0.7388 - val_loss: 0.6205 - val_auc: 0.5485 - val_binary_accuracy: 0.7261
# Epoch 25/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5346 - auc: 0.7189 - binary_accuracy: 0.7406
# Epoch 00025: val_auc did not improve from 0.63876
#
# Epoch 00025: val_loss did not improve from 0.58447
# 964/964 [==============================] - 19s 20ms/sample - loss: 0.5346 - auc: 0.7186 - binary_accuracy: 0.7407 - val_loss: 0.6447 - val_auc: 0.5247 - val_binary_accuracy: 0.7261
# Epoch 26/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5313 - auc: 0.7240 - binary_accuracy: 0.7378
# Epoch 00026: val_auc did not improve from 0.63876
#
# Epoch 00026: val_loss did not improve from 0.58447
# 964/964 [==============================] - 25s 26ms/sample - loss: 0.5319 - auc: 0.7227 - binary_accuracy: 0.7378 - val_loss: 0.7485 - val_auc: 0.5460 - val_binary_accuracy: 0.6640
# Epoch 27/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5294 - auc: 0.7241 - binary_accuracy: 0.7419
# Epoch 00027: val_auc did not improve from 0.63876
#
# Epoch 00027: val_loss did not improve from 0.58447
# 964/964 [==============================] - 25s 25ms/sample - loss: 0.5293 - auc: 0.7240 - binary_accuracy: 0.7422 - val_loss: 0.6156 - val_auc: 0.5837 - val_binary_accuracy: 0.7163
# Epoch 28/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5177 - auc: 0.7413 - binary_accuracy: 0.7396  ETA: 13s - loss: 0.5327 - auc: 0.
# Epoch 00028: val_auc did not improve from 0.63876
#
# Epoch 00028: val_loss did not improve from 0.58447
# 964/964 [==============================] - 29s 30ms/sample - loss: 0.5175 - auc: 0.7415 - binary_accuracy: 0.7399 - val_loss: 0.8691 - val_auc: 0.5104 - val_binary_accuracy: 0.6383
# Epoch 29/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5324 - auc: 0.7193 - binary_accuracy: 0.7414
# Epoch 00029: val_auc did not improve from 0.63876
#
# Epoch 00029: val_loss did not improve from 0.58447
# 964/964 [==============================] - 18s 19ms/sample - loss: 0.5320 - auc: 0.7197 - binary_accuracy: 0.7414 - val_loss: 0.7291 - val_auc: 0.5523 - val_binary_accuracy: 0.6871
# Epoch 30/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5280 - auc: 0.7318 - binary_accuracy: 0.7354
# Epoch 00030: val_auc did not improve from 0.63876
#
# Epoch 00030: val_loss did not improve from 0.58447
# 964/964 [==============================] - 25s 26ms/sample - loss: 0.5284 - auc: 0.7311 - binary_accuracy: 0.7355 - val_loss: 0.6784 - val_auc: 0.5829 - val_binary_accuracy: 0.6941
# Epoch 31/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5282 - auc: 0.7306 - binary_accuracy: 0.7430
# Epoch 00031: val_auc did not improve from 0.63876
#
# Epoch 00031: val_loss did not improve from 0.58447
# 964/964 [==============================] - 25s 25ms/sample - loss: 0.5282 - auc: 0.7307 - binary_accuracy: 0.7430 - val_loss: 0.6218 - val_auc: 0.5783 - val_binary_accuracy: 0.7305
# Epoch 32/50
# 960/964 [============================>.] - ETA: 0s - loss: 0.5296 - auc: 0.7254 - binary_accuracy: 0.7409
# Epoch 00032: val_auc did not improve from 0.63876
#
# Epoch 00032: val_loss did not improve from 0.58447
# 964/964 [==============================] - 28s 29ms/sample - loss: 0.5302 - auc: 0.7246 - binary_accuracy: 0.7407 - val_loss: 0.6074 - val_auc: 0.5835 - val_binary_accuracy: 0.7296
# 'y={"lb":labels["lb"],\n    "lm":labels["lm"],\n    "rm":labels["rm"],\n    "rb":labels["rb"]}\n    \n'

# %%
for i in history.history.keys():
  if "val" in i:
    continue
  # plot loss during training
  pyplot.subplot(211)
  pyplot.title(i)
  pyplot.plot(history.history[i], label='train')
  pyplot.plot(history.history['val_'+i], label='test')
  pyplot.show()

# %% [markdown]
# <h3 style="color:blue"> CROSS VAL 4/5 </h3>

# %%
col=["case","left_cc","left_mlo","right_cc","right_mlo","lb","lm","rb","rm"]
dtypes={"case": "str","left_cc": "str","left_mlo": "str","right_cc": "str","right_mlo": "str","lb": "int","lm": "int","rb": "int","rm": "int"}
df_training=pd.read_csv(directory+'/training_4.csv', sep=',', names=col,dtype=dtypes,  header=None)
df_validation=pd.read_csv(directory+'/validation_4.csv', sep=',', names=col,dtype=dtypes,  header=None)
#df_test=pd.read_csv(directory+'/test_r.csv', sep=',', names=col,dtype=dtypes,  header=None)

def read_spectograms(file_paths, img_rows, img_cols, channels):

  images = []
  
  for file_path in file_paths:
    if file_path=="nan":
        continue
    images.append(imread(file_path))
  
  images = np.asarray(images, dtype=np.float32)
  
  # normalize
  images = images / 255
  
  # reshape to match Keras expectaions
  images = images.reshape(images.shape[0], img_rows, img_cols, channels)

  return images


x_train_left_mlo = read_spectograms(df_training.left_mlo.values, img_rows, img_cols, in_channel)
x_train_left_cc= read_spectograms(df_training.left_cc.values, img_rows, img_cols, in_channel)

###Right

x_train_right_mlo = read_spectograms(df_training.right_mlo.values, img_rows, img_cols, in_channel)
x_train_right_cc= read_spectograms(df_training.right_cc.values, img_rows, img_cols, in_channel)

###labels

from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
labels = df_training[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels=labels.values
labels
print(type(labels))

x_validation_left_mlo = read_spectograms(df_validation.left_mlo.values, img_rows, img_cols, in_channel)
x_validation_left_cc= read_spectograms(df_validation.left_cc.values, img_rows, img_cols, in_channel)

x_validation_right_mlo = read_spectograms(df_validation.right_mlo.values, img_rows, img_cols, in_channel)
x_validation_right_cc= read_spectograms(df_validation.right_cc.values, img_rows, img_cols, in_channel)


mlb = MultiLabelBinarizer()
labels_validation = df_validation[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels_validation=labels_validation.values
labels_validation
print(type(labels_validation))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#  V 2

def resnetBlock(inputimage,k=2,striede=1, name=""):

  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(inputimage)


  activation=keras.activations.relu(batch_normalize )

  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(3,3),
    name="",
  padding="same"
  )(activation)

  conv1x1_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(1,1),
    name="",
#    activation=keras.activations.relu
  )(activation)


  batch_normalize_2 = keras.layers.BatchNormalization( axis=-1,name="")(conv3x3_1)

  activation2=keras.activations.relu(batch_normalize_2 )
  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    kernel_size=(3,3),
    name="",
    padding="same"
  )(activation2)

  outputs=keras.layers.Add()([conv3x3_1,conv1x1_1])
  return outputs


def resNetLayers(inputimage,name=""):
  block1=resnetBlock(inputimage,k=16,name="block1")
  #block2=resnetBlock(block1,k=16,name="block2")
  block3=resnetBlock(block1,k=16,striede=2,name="block3")
  #block4=resnetBlock(block3,k=32,name="block4")
  block5=resnetBlock(block3,k=32,striede=2,name="block5")
  pool=keras.layers.AveragePooling2D(
      pool_size=(3,3), strides=2, padding='same', name='' #(3,3)
  )(block5)
  #block6=resnetBlock(block5,k=32,striede=2,name="block6")
  block7=resnetBlock(pool,k=32,striede=2,name="block7")
  #block8=resnetBlock(inputfilter=128,k=128,name="block8")(block7)
  
  #block10=resnetBlock(inputfilter=256,k=256,name="block10")(block9)
  return block7

def singleViewResnet(inputimage, name=""):

  conv7x7=tf.keras.layers.Conv2D(
    filters=16,
    strides=2,
    kernel_size=(5,5),
    name="",
    activation=keras.activations.relu
  )(inputimage)

  pool3x3=keras.layers.AveragePooling2D(
      pool_size=(2,2), strides=2, padding='same', name='' #(3,3)
  )(conv7x7)

  resNetL=resNetLayers(pool3x3,name="")
  print(resNetL.shape)
  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(resNetL)

  relu=keras.activations.relu(batch_normalize)
  
  return relu


def view_wise(img_rows=300, img_cols=300):
  left_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_cc")
  right_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_cc"
  )  

  left_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_mlo"
  )  
  right_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_mlo"
  )

  #cc_resnet=singleViewResnet(name="cc_resnet")
  #mlo_resnet=singleViewResnet(name="mlo_resnet")

  cc_resnet_left=singleViewResnet(left_cc_input)
  cc_resnet_right=singleViewResnet(right_cc_input)

  mlo_resnet_left=singleViewResnet(left_mlo_input)
  mlo_resent_right=singleViewResnet(right_mlo_input)

  avg_pool_cc_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_left)
  avg_pool_cc_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_right)

  avg_pool_mlo_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resnet_left)
  avg_pool_mlo_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resent_right)

  mlo=keras.layers.Concatenate(axis=-1)([avg_pool_mlo_left, avg_pool_mlo_right])
  cc=keras.layers.Concatenate(axis=-1)([avg_pool_cc_left, avg_pool_cc_right])

  mlo_flatten=tf.keras.layers.Flatten()(mlo)
  cc_flatten=tf.keras.layers.Flatten()(cc)

  """
  mlo_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(256,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(mlo_flatten)
    )
  """
  mlo_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_flatten)
        )
      )
  mlo_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_dense1)
        )
      ) 
  
  mlo_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(mlo_dense3)
    )
  
  """
  cc_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(512,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(cc_flatten)
    )
  """
  

  cc_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_flatten)
        )
      )
  cc_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_dense1)
        )
      ) 
 
  cc_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(cc_dense3)
    )
  
  
  
  """mlo_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rb")(mlo_dense2)
  mlo_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rm")(mlo_dense2)
  mlo_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lb")(mlo_dense2)
  mlo_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lm")(mlo_dense2)
  
  cc_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rb")(cc_dense2)
  cc_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rm")(cc_dense2)
  cc_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lb")(cc_dense2)
  cc_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lm")(cc_dense2)
  
  rb_output = keras.layers.Average(name="rb")([mlo_rb,cc_rb])
  rm_output = keras.layers.Average(name="rm")([mlo_rm,cc_rm])
  lb_output = keras.layers.Average(name="lb")([mlo_lb,cc_lb])
  lm_output = keras.layers.Average(name="lm")([mlo_lm,cc_lm])"""

  output=keras.layers.Average(name="outpu")([cc_dense2,mlo_dense2])

  output=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(output)
    )
  
 
  output=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(4,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(output)
    )

  return keras.Model(
      inputs=[left_cc_input, right_cc_input, left_mlo_input, right_mlo_input],
      outputs=output,name="view-wise"
  )
model=view_wise(img_rows, img_cols)
model.summary()
#keras.utils.plot_model(model, "/gdrive/My Drive/Colab_Notebooks/NNPROJECT/image_Net/view-wise.png", show_shapes=True, expand_nested=False)
# Out:
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# Model: "view-wise"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_cc (InputLayer)            [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# right_cc (InputLayer)           [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# left_mlo (InputLayer)           [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# right_mlo (InputLayer)          [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 254, 190, 16) 1216        left_cc[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 254, 190, 16) 1216        right_cc[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 254, 190, 16) 1216        left_mlo[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 254, 190, 16) 1216        right_mlo[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 127, 95, 16)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 127, 95, 16)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 127, 95, 16)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 127, 95, 16)  0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 127, 95, 16)  64          average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 127, 95, 16)  64          average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 127, 95, 16)  64          average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 127, 95, 16)  64          average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu (TensorFlowOpL [(None, 127, 95, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_9 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_18 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_27 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 127, 95, 16)  2320        tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 127, 95, 16)  64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 127, 95, 16)  64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 127, 95, 16)  64          conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 127, 95, 16)  64          conv2d_40[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_1 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_10 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_19 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_28 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 127, 95, 16)  2320        tf_op_layer_Relu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 127, 95, 16)  272         tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_28[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_27[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 127, 95, 16)  0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 127, 95, 16)  0           conv2d_16[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 127, 95, 16)  0           conv2d_29[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 127, 95, 16)  0           conv2d_42[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 127, 95, 16)  64          add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 127, 95, 16)  64          add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 127, 95, 16)  64          add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 127, 95, 16)  64          add_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_2 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_11 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_20 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_29 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 48, 16)   2320        tf_op_layer_Relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 48, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 48, 16)   64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 48, 16)   64          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 48, 16)   64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_3 (TensorFlowO [(None, 64, 48, 16)] 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_12 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_21 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_30 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 48, 16)   2320        tf_op_layer_Relu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 48, 16)   272         tf_op_layer_Relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_30[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 48, 16)   0           conv2d_6[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 48, 16)   0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 48, 16)   0           conv2d_32[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 48, 16)   0           conv2d_45[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 48, 16)   64          add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 48, 16)   64          add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 48, 16)   64          add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 48, 16)   64          add_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_4 (TensorFlowO [(None, 64, 48, 16)] 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_13 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_22 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_31 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 24, 32)   4640        tf_op_layer_Relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 24, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 24, 32)   128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 24, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 24, 32)   128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_5 (TensorFlowO [(None, 32, 24, 32)] 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_14 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_23 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_32 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 24, 32)   9248        tf_op_layer_Relu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 24, 32)   544         tf_op_layer_Relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_32[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_31[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 24, 32)   0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 24, 32)   0           conv2d_22[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 24, 32)   0           conv2d_35[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 24, 32)   0           conv2d_48[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 16, 12, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 16, 12, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 16, 12, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 16, 12, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 12, 32)   128         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_6 (TensorFlowO [(None, 16, 12, 32)] 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_15 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_24 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_33 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 6, 32)     128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 6, 32)     128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 6, 32)     128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 6, 32)     128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_7 (TensorFlowO [(None, 8, 6, 32)]   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_16 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_25 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_34 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_34[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_33[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 6, 32)     0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 6, 32)     0           conv2d_25[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 6, 32)     0           conv2d_38[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 6, 32)     0           conv2d_51[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 6, 32)     128         add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 6, 32)     128         add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 6, 32)     128         add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 6, 32)     128         add_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_8 (TensorFlowO [(None, 8, 6, 32)]   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_17 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_26 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_35 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 4, 3, 32)     0           tf_op_layer_Relu_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 4, 3, 32)     0           tf_op_layer_Relu_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 4, 3, 32)     0           tf_op_layer_Relu_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 4, 3, 32)     0           tf_op_layer_Relu_35[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 3, 64)     0           average_pooling2d_8[0][0]
#                                                                  average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 3, 64)     0           average_pooling2d_10[0][0]
#                                                                  average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 768)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 768)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2048)         1574912     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         1574912     flatten[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 2048)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 2048)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2048)         0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024)         2098176     dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     dropout[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 1024)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           65600       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           65600       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# outpu (Average)                 (None, 64)           0           dropout_5[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           4160        outpu[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 4)            260         dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 4)            0           dense_7[0][0]
# ==================================================================================================
# Total params: 7,665,220
# Trainable params: 7,663,556
# Non-trainable params: 1,664
# __________________________________________________________________________________________________

# %%
batch_size=32
step_per_epoch=len(x_train_left_mlo)/batch_size

cbks = [tf.keras.callbacks.EarlyStopping(patience=10, monitor="val_loss"),
        tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_auc4",
                    monitor="val_auc",
                    mode="max",
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
                    
        ),
       tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_loss4",
                    monitor="val_loss",
                    
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
       )]


model.compile(#optimizer=keras.optimizers.Adam(lr=0.001),
              #optimizer=keras.optimizers.SGD(lr=0.0005, decay=1e-6, momentum=0.9, nesterov=True),
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005,rho=0.9,momentum=0.9,epsilon=1e-07),
              loss=keras.losses.BinaryCrossentropy(),
              #loss=custom_loss,
              metrics=[tf.keras.metrics.AUC(name="auc"),tf.keras.metrics.BinaryAccuracy(threshold=0.5)]#tf.keras.metrics.BinaryAccuracy(threshold=0.01)]#,
             )

history=model.fit(x={"left_mlo": x_train_left_mlo,
                         "left_cc": x_train_left_cc,
                         "right_mlo":x_train_right_mlo,
                         "right_cc":x_train_right_cc},
                  y=labels.values,
                  epochs=50,verbose=1,
                  callbacks=cbks,
                  validation_data=(
                      {"left_mlo": x_validation_left_mlo,
                         "left_cc": x_validation_left_cc,
                         "right_mlo":x_validation_right_mlo,
                         "right_cc":x_validation_right_cc},
                    labels_validation.values
                  ))

"""y={"lb":labels["lb"],
    "lm":labels["lm"],
    "rm":labels["rm"],
    "rb":labels["rb"]}
    
"""
# Out:
# Train on 1036 samples, validate on 210 samples
# Epoch 1/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 1.1054 - auc: 0.5145 - binary_accuracy: 0.7085
# Epoch 00001: val_auc improved from -inf to 0.51036, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc4
# WARNING:tensorflow:From c:\users\lpatr\.virtualenvs\proj-r1r8_6rp\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc4\assets
#
# Epoch 00001: val_loss improved from inf to 1.04044, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4\assets
# 1036/1036 [==============================] - 82s 79ms/sample - loss: 1.1044 - auc: 0.5156 - binary_accuracy: 0.7090 - val_loss: 1.0404 - val_auc: 0.5104 - val_binary_accuracy: 0.7345
# Epoch 2/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.9776 - auc: 0.6333 - binary_accuracy: 0.7336
# Epoch 00002: val_auc did not improve from 0.51036
#
# Epoch 00002: val_loss improved from 1.04044 to 0.96259, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4\assets
# 1036/1036 [==============================] - 60s 58ms/sample - loss: 0.9774 - auc: 0.6326 - binary_accuracy: 0.7333 - val_loss: 0.9626 - val_auc: 0.4913 - val_binary_accuracy: 0.7345
# Epoch 3/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.8907 - auc: 0.6633 - binary_accuracy: 0.7244
# Epoch 00003: val_auc did not improve from 0.51036
#
# Epoch 00003: val_loss improved from 0.96259 to 0.94924, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4\assets
# 1036/1036 [==============================] - 98s 94ms/sample - loss: 0.8901 - auc: 0.6633 - binary_accuracy: 0.7247 - val_loss: 0.9492 - val_auc: 0.3685 - val_binary_accuracy: 0.7345
# Epoch 4/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.8244 - auc: 0.6735 - binary_accuracy: 0.7329
# Epoch 00004: val_auc did not improve from 0.51036
#
# Epoch 00004: val_loss improved from 0.94924 to 0.85358, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4\assets
# 1036/1036 [==============================] - 51s 50ms/sample - loss: 0.8232 - auc: 0.6750 - binary_accuracy: 0.7331 - val_loss: 0.8536 - val_auc: 0.4695 - val_binary_accuracy: 0.7345
# Epoch 5/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.7624 - auc: 0.6944 - binary_accuracy: 0.7266
# Epoch 00005: val_auc did not improve from 0.51036
#
# Epoch 00005: val_loss improved from 0.85358 to 0.82550, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4\assets
# 1036/1036 [==============================] - 50s 49ms/sample - loss: 0.7620 - auc: 0.6941 - binary_accuracy: 0.7271 - val_loss: 0.8255 - val_auc: 0.4750 - val_binary_accuracy: 0.7345
# Epoch 6/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.7250 - auc: 0.6854 - binary_accuracy: 0.7322
# Epoch 00006: val_auc did not improve from 0.51036
#
# Epoch 00006: val_loss improved from 0.82550 to 0.81046, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4\assets
# 1036/1036 [==============================] - 52s 50ms/sample - loss: 0.7243 - auc: 0.6863 - binary_accuracy: 0.7326 - val_loss: 0.8105 - val_auc: 0.4934 - val_binary_accuracy: 0.7345
# Epoch 7/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.6889 - auc: 0.6904 - binary_accuracy: 0.7307
# Epoch 00007: val_auc did not improve from 0.51036
#
# Epoch 00007: val_loss improved from 0.81046 to 0.77757, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4\assets
# 1036/1036 [==============================] - 59s 57ms/sample - loss: 0.6878 - auc: 0.6918 - binary_accuracy: 0.7309 - val_loss: 0.7776 - val_auc: 0.3521 - val_binary_accuracy: 0.7345
# Epoch 8/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.6566 - auc: 0.7003 - binary_accuracy: 0.7317
# Epoch 00008: val_auc did not improve from 0.51036
#
# Epoch 00008: val_loss did not improve from 0.77757
# 1036/1036 [==============================] - 30s 29ms/sample - loss: 0.6575 - auc: 0.6985 - binary_accuracy: 0.7314 - val_loss: 0.7969 - val_auc: 0.3783 - val_binary_accuracy: 0.6917
# Epoch 9/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.6303 - auc: 0.7117 - binary_accuracy: 0.7332
# Epoch 00009: val_auc did not improve from 0.51036
#
# Epoch 00009: val_loss did not improve from 0.77757
# 1036/1036 [==============================] - 21s 20ms/sample - loss: 0.6308 - auc: 0.7108 - binary_accuracy: 0.7333 - val_loss: 0.8190 - val_auc: 0.3248 - val_binary_accuracy: 0.7345
# Epoch 10/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.6051 - auc: 0.7229 - binary_accuracy: 0.7329
# Epoch 00010: val_auc did not improve from 0.51036
#
# Epoch 00010: val_loss did not improve from 0.77757
# 1036/1036 [==============================] - 22s 22ms/sample - loss: 0.6068 - auc: 0.7202 - binary_accuracy: 0.7321 - val_loss: 0.8678 - val_auc: 0.4235 - val_binary_accuracy: 0.6464
# Epoch 11/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5974 - auc: 0.7083 - binary_accuracy: 0.7329
# Epoch 00011: val_auc improved from 0.51036 to 0.52295, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc4\assets
#
# Epoch 00011: val_loss improved from 0.77757 to 0.70636, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4\assets
# 1036/1036 [==============================] - 64s 62ms/sample - loss: 0.5974 - auc: 0.7081 - binary_accuracy: 0.7331 - val_loss: 0.7064 - val_auc: 0.5229 - val_binary_accuracy: 0.7321
# Epoch 12/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5835 - auc: 0.7180 - binary_accuracy: 0.7329
# Epoch 00012: val_auc did not improve from 0.52295
#
# Epoch 00012: val_loss did not improve from 0.70636
# 1036/1036 [==============================] - 28s 27ms/sample - loss: 0.5831 - auc: 0.7186 - binary_accuracy: 0.7341 - val_loss: 0.7386 - val_auc: 0.4043 - val_binary_accuracy: 0.7345
# Epoch 13/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5679 - auc: 0.7245 - binary_accuracy: 0.7363
# Epoch 00013: val_auc did not improve from 0.52295
#
# Epoch 00013: val_loss did not improve from 0.70636
# 1036/1036 [==============================] - 22s 21ms/sample - loss: 0.5675 - auc: 0.7248 - binary_accuracy: 0.7360 - val_loss: 0.8160 - val_auc: 0.3054 - val_binary_accuracy: 0.6631
# Epoch 14/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5617 - auc: 0.7271 - binary_accuracy: 0.7410
# Epoch 00014: val_auc did not improve from 0.52295
#
# Epoch 00014: val_loss did not improve from 0.70636
# 1036/1036 [==============================] - 23s 22ms/sample - loss: 0.5619 - auc: 0.7263 - binary_accuracy: 0.7408 - val_loss: 0.7582 - val_auc: 0.3799 - val_binary_accuracy: 0.7107
# Epoch 15/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5558 - auc: 0.7250 - binary_accuracy: 0.7310
# Epoch 00015: val_auc did not improve from 0.52295
#
# Epoch 00015: val_loss did not improve from 0.70636
# 1036/1036 [==============================] - 22s 22ms/sample - loss: 0.5564 - auc: 0.7234 - binary_accuracy: 0.7314 - val_loss: 0.8372 - val_auc: 0.4802 - val_binary_accuracy: 0.6452
# Epoch 16/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5474 - auc: 0.7290 - binary_accuracy: 0.7332
# Epoch 00016: val_auc did not improve from 0.52295
#
# Epoch 00016: val_loss improved from 0.70636 to 0.67419, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss4\assets
# 1036/1036 [==============================] - 50s 49ms/sample - loss: 0.5476 - auc: 0.7289 - binary_accuracy: 0.7326 - val_loss: 0.6742 - val_auc: 0.3338 - val_binary_accuracy: 0.7345
# Epoch 17/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5559 - auc: 0.7077 - binary_accuracy: 0.7361
# Epoch 00017: val_auc did not improve from 0.52295
#
# Epoch 00017: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 41s 39ms/sample - loss: 0.5556 - auc: 0.7078 - binary_accuracy: 0.7365 - val_loss: 0.6950 - val_auc: 0.3611 - val_binary_accuracy: 0.7321
# Epoch 18/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5479 - auc: 0.7174 - binary_accuracy: 0.7378
# Epoch 00018: val_auc did not improve from 0.52295
#
# Epoch 00018: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 24s 23ms/sample - loss: 0.5474 - auc: 0.7178 - binary_accuracy: 0.7382 - val_loss: 0.7816 - val_auc: 0.3160 - val_binary_accuracy: 0.7310
# Epoch 19/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5468 - auc: 0.7117 - binary_accuracy: 0.7356
# Epoch 00019: val_auc did not improve from 0.52295
#
# Epoch 00019: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 18s 17ms/sample - loss: 0.5471 - auc: 0.7111 - binary_accuracy: 0.7355 - val_loss: 0.7493 - val_auc: 0.3250 - val_binary_accuracy: 0.7321
# Epoch 20/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5260 - auc: 0.7416 - binary_accuracy: 0.7375
# Epoch 00020: val_auc did not improve from 0.52295
#
# Epoch 00020: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 19s 18ms/sample - loss: 0.5259 - auc: 0.7416 - binary_accuracy: 0.7379 - val_loss: 0.7816 - val_auc: 0.3735 - val_binary_accuracy: 0.6905
# Epoch 21/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5344 - auc: 0.7286 - binary_accuracy: 0.7341
# Epoch 00021: val_auc did not improve from 0.52295
#
# Epoch 00021: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 17s 16ms/sample - loss: 0.5340 - auc: 0.7294 - binary_accuracy: 0.7346 - val_loss: 0.8373 - val_auc: 0.3079 - val_binary_accuracy: 0.6405
# Epoch 22/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5285 - auc: 0.7343 - binary_accuracy: 0.7363
# Epoch 00022: val_auc did not improve from 0.52295
#
# Epoch 00022: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 16s 16ms/sample - loss: 0.5288 - auc: 0.7341 - binary_accuracy: 0.7358 - val_loss: 0.8024 - val_auc: 0.3160 - val_binary_accuracy: 0.6821
# Epoch 23/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5209 - auc: 0.7444 - binary_accuracy: 0.7439
# Epoch 00023: val_auc did not improve from 0.52295
#
# Epoch 00023: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 16s 16ms/sample - loss: 0.5219 - auc: 0.7433 - binary_accuracy: 0.7435 - val_loss: 0.6964 - val_auc: 0.3335 - val_binary_accuracy: 0.7345
# Epoch 24/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5159 - auc: 0.7518 - binary_accuracy: 0.7458
# Epoch 00024: val_auc did not improve from 0.52295
#
# Epoch 00024: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 16s 15ms/sample - loss: 0.5168 - auc: 0.7504 - binary_accuracy: 0.7447 - val_loss: 0.8039 - val_auc: 0.3503 - val_binary_accuracy: 0.6583
# Epoch 25/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5171 - auc: 0.7478 - binary_accuracy: 0.7441
# Epoch 00025: val_auc did not improve from 0.52295
#
# Epoch 00025: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 15s 14ms/sample - loss: 0.5166 - auc: 0.7482 - binary_accuracy: 0.7447 - val_loss: 0.7689 - val_auc: 0.3558 - val_binary_accuracy: 0.6810
# Epoch 26/50
# 1024/1036 [============================>.] - ETA: 0s - loss: 0.5165 - auc: 0.7485 - binary_accuracy: 0.7449
# Epoch 00026: val_auc did not improve from 0.52295
#
# Epoch 00026: val_loss did not improve from 0.67419
# 1036/1036 [==============================] - 17s 17ms/sample - loss: 0.5166 - auc: 0.7484 - binary_accuracy: 0.7442 - val_loss: 0.7639 - val_auc: 0.3479 - val_binary_accuracy: 0.7202
# 'y={"lb":labels["lb"],\n    "lm":labels["lm"],\n    "rm":labels["rm"],\n    "rb":labels["rb"]}\n    \n'

# %%
for i in history.history.keys():
  if "val" in i:
    continue
  # plot loss during training
  pyplot.subplot(211)
  pyplot.title(i)
  pyplot.plot(history.history[i], label='train')
  pyplot.plot(history.history['val_'+i], label='test')
  pyplot.show()

# %% [markdown]
# <h3 style="color:blue"> CROSS VAL 5/5 </h3>

# %%
col=["case","left_cc","left_mlo","right_cc","right_mlo","lb","lm","rb","rm"]
dtypes={"case": "str","left_cc": "str","left_mlo": "str","right_cc": "str","right_mlo": "str","lb": "int","lm": "int","rb": "int","rm": "int"}
df_training=pd.read_csv(directory+'/training_5.csv', sep=',', names=col,dtype=dtypes,  header=None)
df_validation=pd.read_csv(directory+'/validation_5.csv', sep=',', names=col,dtype=dtypes,  header=None)
#df_test=pd.read_csv(directory+'/test_r.csv', sep=',', names=col,dtype=dtypes,  header=None)

def read_spectograms(file_paths, img_rows, img_cols, channels):

  images = []
  
  for file_path in file_paths:
    if file_path=="nan":
        continue
    images.append(imread(file_path))
  
  images = np.asarray(images, dtype=np.float32)
  
  # normalize
  images = images / 255
  
  # reshape to match Keras expectaions
  images = images.reshape(images.shape[0], img_rows, img_cols, channels)

  return images


x_train_left_mlo = read_spectograms(df_training.left_mlo.values, img_rows, img_cols, in_channel)
x_train_left_cc= read_spectograms(df_training.left_cc.values, img_rows, img_cols, in_channel)

###Right

x_train_right_mlo = read_spectograms(df_training.right_mlo.values, img_rows, img_cols, in_channel)
x_train_right_cc= read_spectograms(df_training.right_cc.values, img_rows, img_cols, in_channel)

###labels

from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
labels = df_training[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels=labels.values
labels
print(type(labels))

x_validation_left_mlo = read_spectograms(df_validation.left_mlo.values, img_rows, img_cols, in_channel)
x_validation_left_cc= read_spectograms(df_validation.left_cc.values, img_rows, img_cols, in_channel)

x_validation_right_mlo = read_spectograms(df_validation.right_mlo.values, img_rows, img_cols, in_channel)
x_validation_right_cc= read_spectograms(df_validation.right_cc.values, img_rows, img_cols, in_channel)


mlb = MultiLabelBinarizer()
labels_validation = df_validation[["lb","lm","rb","rm"]].reset_index(drop=True)
#labels_validation=labels_validation.values
labels_validation
print(type(labels_validation))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#  V 2

def resnetBlock(inputimage,k=2,striede=1, name=""):

  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(inputimage)


  activation=keras.activations.relu(batch_normalize )

  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(3,3),
    name="",
  padding="same"
  )(activation)

  conv1x1_1=tf.keras.layers.Conv2D(
    filters=k,
    strides=striede,
    kernel_size=(1,1),
    name="",
#    activation=keras.activations.relu
  )(activation)


  batch_normalize_2 = keras.layers.BatchNormalization( axis=-1,name="")(conv3x3_1)

  activation2=keras.activations.relu(batch_normalize_2 )
  conv3x3_1=tf.keras.layers.Conv2D(
    filters=k,
    kernel_size=(3,3),
    name="",
    padding="same"
  )(activation2)

  outputs=keras.layers.Add()([conv3x3_1,conv1x1_1])
  return outputs


def resNetLayers(inputimage,name=""):
  block1=resnetBlock(inputimage,k=16,name="block1")
  #block2=resnetBlock(block1,k=16,name="block2")
  block3=resnetBlock(block1,k=16,striede=2,name="block3")
  #block4=resnetBlock(block3,k=32,name="block4")
  block5=resnetBlock(block3,k=32,striede=2,name="block5")
  pool=keras.layers.AveragePooling2D(
      pool_size=(3,3), strides=2, padding='same', name='' #(3,3)
  )(block5)
  #block6=resnetBlock(block5,k=32,striede=2,name="block6")
  block7=resnetBlock(pool,k=32,striede=2,name="block7")
  #block8=resnetBlock(inputfilter=128,k=128,name="block8")(block7)
  
  #block10=resnetBlock(inputfilter=256,k=256,name="block10")(block9)
  return block7

def singleViewResnet(inputimage, name=""):

  conv7x7=tf.keras.layers.Conv2D(
    filters=16,
    strides=2,
    kernel_size=(5,5),
    name="",
    activation=keras.activations.relu
  )(inputimage)

  pool3x3=keras.layers.AveragePooling2D(
      pool_size=(2,2), strides=2, padding='same', name='' #(3,3)
  )(conv7x7)

  resNetL=resNetLayers(pool3x3,name="")
  print(resNetL.shape)
  batch_normalize = keras.layers.BatchNormalization( axis=-1,name="")(resNetL)

  relu=keras.activations.relu(batch_normalize)
  
  return relu


def view_wise(img_rows=300, img_cols=300):
  left_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_cc")
  right_cc_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_cc"
  )  

  left_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="left_mlo"
  )  
  right_mlo_input = keras.Input(
      shape=(img_rows, img_cols, 3), name="right_mlo"
  )

  #cc_resnet=singleViewResnet(name="cc_resnet")
  #mlo_resnet=singleViewResnet(name="mlo_resnet")

  cc_resnet_left=singleViewResnet(left_cc_input)
  cc_resnet_right=singleViewResnet(right_cc_input)

  mlo_resnet_left=singleViewResnet(left_mlo_input)
  mlo_resent_right=singleViewResnet(right_mlo_input)

  avg_pool_cc_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_left)
  avg_pool_cc_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(cc_resnet_right)

  avg_pool_mlo_left=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resnet_left)
  avg_pool_mlo_right=tf.keras.layers.AveragePooling2D(
    pool_size=(2, 2), padding='same')(mlo_resent_right)

  mlo=keras.layers.Concatenate(axis=-1)([avg_pool_mlo_left, avg_pool_mlo_right])
  cc=keras.layers.Concatenate(axis=-1)([avg_pool_cc_left, avg_pool_cc_right])

  mlo_flatten=tf.keras.layers.Flatten()(mlo)
  cc_flatten=tf.keras.layers.Flatten()(cc)

  """
  mlo_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(256,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(mlo_flatten)
    )
  """
  mlo_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_flatten)
        )
      )
  mlo_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(mlo_dense1)
        )
      ) 
  
  mlo_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(mlo_dense3)
    )
  
  """
  cc_dense1=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.Dense(512,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(cc_flatten)
    )
  """
  

  cc_dense1=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(2048,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_flatten)
        )
      )
  cc_dense3=tf.keras.layers.Dropout(.2)(
      tf.keras.layers.LeakyReLU(alpha=0.1)(
          tf.keras.layers.Dense(1024,
          kernel_regularizer=tf.keras.regularizers.l2(regl2))(cc_dense1)
        )
      ) 
 
  cc_dense2=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(cc_dense3)
    )
  
  
  
  """mlo_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rb")(mlo_dense2)
  mlo_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_rm")(mlo_dense2)
  mlo_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lb")(mlo_dense2)
  mlo_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="mlo_lm")(mlo_dense2)
  
  cc_rb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rb")(cc_dense2)
  cc_rm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_rm")(cc_dense2)
  cc_lb=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lb")(cc_dense2)
  cc_lm=tf.keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=tf.keras.regularizers.l2(regl2),name="cc_lm")(cc_dense2)
  
  rb_output = keras.layers.Average(name="rb")([mlo_rb,cc_rb])
  rm_output = keras.layers.Average(name="rm")([mlo_rm,cc_rm])
  lb_output = keras.layers.Average(name="lb")([mlo_lb,cc_lb])
  lm_output = keras.layers.Average(name="lm")([mlo_lm,cc_lm])"""

  output=keras.layers.Average(name="outpu")([cc_dense2,mlo_dense2])

  output=tf.keras.layers.Dropout(.3)(
      tf.keras.layers.Dense(64,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="relu")(output)
    )
  
 
  output=tf.keras.layers.Dropout(.0)(
      tf.keras.layers.Dense(4,
      kernel_regularizer=tf.keras.regularizers.l2(regl2),activation="sigmoid")(output)
    )

  return keras.Model(
      inputs=[left_cc_input, right_cc_input, left_mlo_input, right_mlo_input],
      outputs=output,name="view-wise"
  )
model=view_wise(img_rows, img_cols)
model.summary()
#keras.utils.plot_model(model, "/gdrive/My Drive/Colab_Notebooks/NNPROJECT/image_Net/view-wise.png", show_shapes=True, expand_nested=False)
# Out:
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# (None, 8, 6, 32)
# Model: "view-wise"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_cc (InputLayer)            [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# right_cc (InputLayer)           [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# left_mlo (InputLayer)           [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# right_mlo (InputLayer)          [(None, 512, 384, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 254, 190, 16) 1216        left_cc[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 254, 190, 16) 1216        right_cc[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 254, 190, 16) 1216        left_mlo[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 254, 190, 16) 1216        right_mlo[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 127, 95, 16)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 127, 95, 16)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 127, 95, 16)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 127, 95, 16)  0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 127, 95, 16)  64          average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 127, 95, 16)  64          average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 127, 95, 16)  64          average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 127, 95, 16)  64          average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu (TensorFlowOpL [(None, 127, 95, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_9 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_18 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_27 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 127, 95, 16)  2320        tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 127, 95, 16)  64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 127, 95, 16)  64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 127, 95, 16)  64          conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 127, 95, 16)  64          conv2d_40[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_1 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_10 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_19 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_28 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 127, 95, 16)  2320        tf_op_layer_Relu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 127, 95, 16)  272         tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 127, 95, 16)  2320        tf_op_layer_Relu_28[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 127, 95, 16)  272         tf_op_layer_Relu_27[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 127, 95, 16)  0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 127, 95, 16)  0           conv2d_16[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 127, 95, 16)  0           conv2d_29[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 127, 95, 16)  0           conv2d_42[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 127, 95, 16)  64          add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 127, 95, 16)  64          add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 127, 95, 16)  64          add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 127, 95, 16)  64          add_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_2 (TensorFlowO [(None, 127, 95, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_11 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_20 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_29 (TensorFlow [(None, 127, 95, 16) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 48, 16)   2320        tf_op_layer_Relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 48, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 48, 16)   64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 48, 16)   64          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 48, 16)   64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_3 (TensorFlowO [(None, 64, 48, 16)] 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_12 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_21 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_30 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 48, 16)   2320        tf_op_layer_Relu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 48, 16)   272         tf_op_layer_Relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 64, 48, 16)   2320        tf_op_layer_Relu_30[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 64, 48, 16)   272         tf_op_layer_Relu_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 48, 16)   0           conv2d_6[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 48, 16)   0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 48, 16)   0           conv2d_32[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 48, 16)   0           conv2d_45[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 48, 16)   64          add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 48, 16)   64          add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 48, 16)   64          add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 48, 16)   64          add_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_4 (TensorFlowO [(None, 64, 48, 16)] 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_13 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_22 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_31 (TensorFlow [(None, 64, 48, 16)] 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 24, 32)   4640        tf_op_layer_Relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 24, 32)   4640        tf_op_layer_Relu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 24, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 24, 32)   128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 24, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 24, 32)   128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_5 (TensorFlowO [(None, 32, 24, 32)] 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_14 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_23 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_32 (TensorFlow [(None, 32, 24, 32)] 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 24, 32)   9248        tf_op_layer_Relu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 24, 32)   544         tf_op_layer_Relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 24, 32)   9248        tf_op_layer_Relu_32[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 24, 32)   544         tf_op_layer_Relu_31[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 24, 32)   0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 24, 32)   0           conv2d_22[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 24, 32)   0           conv2d_35[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 24, 32)   0           conv2d_48[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 16, 12, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 16, 12, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 16, 12, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 16, 12, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 12, 32)   128         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 12, 32)   128         average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_6 (TensorFlowO [(None, 16, 12, 32)] 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_15 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_24 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_33 (TensorFlow [(None, 16, 12, 32)] 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 6, 32)     128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 6, 32)     128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 6, 32)     128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 6, 32)     128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_7 (TensorFlowO [(None, 8, 6, 32)]   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_16 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_25 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_34 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 6, 32)     9248        tf_op_layer_Relu_34[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 6, 32)     1056        tf_op_layer_Relu_33[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 6, 32)     0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 6, 32)     0           conv2d_25[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 6, 32)     0           conv2d_38[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 6, 32)     0           conv2d_51[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 6, 32)     128         add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 6, 32)     128         add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 6, 32)     128         add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 6, 32)     128         add_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_8 (TensorFlowO [(None, 8, 6, 32)]   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_17 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_26 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_35 (TensorFlow [(None, 8, 6, 32)]   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 4, 3, 32)     0           tf_op_layer_Relu_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 4, 3, 32)     0           tf_op_layer_Relu_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 4, 3, 32)     0           tf_op_layer_Relu_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 4, 3, 32)     0           tf_op_layer_Relu_35[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 3, 64)     0           average_pooling2d_8[0][0]
#                                                                  average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 3, 64)     0           average_pooling2d_10[0][0]
#                                                                  average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 768)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 768)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2048)         1574912     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         1574912     flatten[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 2048)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 2048)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2048)         0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024)         2098176     dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     dropout[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 1024)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           65600       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           65600       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# outpu (Average)                 (None, 64)           0           dropout_5[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           4160        outpu[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 4)            260         dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 4)            0           dense_7[0][0]
# ==================================================================================================
# Total params: 7,665,220
# Trainable params: 7,663,556
# Non-trainable params: 1,664
# __________________________________________________________________________________________________

# %%
batch_size=32
step_per_epoch=len(x_train_left_mlo)/batch_size


cbks = [tf.keras.callbacks.EarlyStopping(patience=10, monitor="val_loss"),
        tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_auc5",
                    monitor="val_auc",
                    mode="max",
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
                    
        ),
       tf.keras.callbacks.ModelCheckpoint(
                    "Z:\\Dataset\\NN_Dataset\\DDSM\\Cachelorenzo\\checkpoint_loss5",
                    monitor="val_loss",
                    
                    verbose=1,
                    save_best_only=True,
                   
                    
                    save_freq="epoch"
       )]

model.compile(#optimizer=keras.optimizers.Adam(lr=0.001),
              #optimizer=keras.optimizers.SGD(lr=0.0005, decay=1e-6, momentum=0.9, nesterov=True),
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0005,rho=0.9,momentum=0.9,epsilon=1e-07),
              loss=keras.losses.BinaryCrossentropy(),
              #loss=custom_loss,
              metrics=[tf.keras.metrics.AUC(name="auc"),tf.keras.metrics.BinaryAccuracy(threshold=0.5)]#tf.keras.metrics.BinaryAccuracy(threshold=0.01)]#,
             )

history=model.fit(x={"left_mlo": x_train_left_mlo,
                         "left_cc": x_train_left_cc,
                         "right_mlo":x_train_right_mlo,
                         "right_cc":x_train_right_cc},
                  y=labels.values,
                  epochs=50,verbose=1,
                  callbacks = cbks,
                  validation_data=(
                      {"left_mlo": x_validation_left_mlo,
                         "left_cc": x_validation_left_cc,
                         "right_mlo":x_validation_right_mlo,
                         "right_cc":x_validation_right_cc},
                    labels_validation.values
                  ))

"""y={"lb":labels["lb"],
    "lm":labels["lm"],
    "rm":labels["rm"],
    "rb":labels["rb"]}
    
"""
# Out:
# Train on 997 samples, validate on 249 samples
# Epoch 1/50
# 992/997 [============================>.] - ETA: 0s - loss: 1.0952 - auc: 0.5345 - binary_accuracy: 0.7243
# Epoch 00001: val_auc improved from -inf to 0.50926, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# WARNING:tensorflow:From c:\users\lpatr\.virtualenvs\proj-r1r8_6rp\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00001: val_loss improved from inf to 1.04015, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 92s 92ms/sample - loss: 1.0950 - auc: 0.5348 - binary_accuracy: 0.7244 - val_loss: 1.0402 - val_auc: 0.5093 - val_binary_accuracy: 0.7400
# Epoch 2/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.9949 - auc: 0.6026 - binary_accuracy: 0.7271
# Epoch 00002: val_auc improved from 0.50926 to 0.53248, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00002: val_loss improved from 1.04015 to 0.99106, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 83s 83ms/sample - loss: 0.9950 - auc: 0.6025 - binary_accuracy: 0.7267 - val_loss: 0.9911 - val_auc: 0.5325 - val_binary_accuracy: 0.7400
# Epoch 3/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.9139 - auc: 0.6174 - binary_accuracy: 0.7308
# Epoch 00003: val_auc did not improve from 0.53248
#
# Epoch 00003: val_loss improved from 0.99106 to 0.89202, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 88s 88ms/sample - loss: 0.9139 - auc: 0.6171 - binary_accuracy: 0.7307 - val_loss: 0.8920 - val_auc: 0.5263 - val_binary_accuracy: 0.7400
# Epoch 4/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.8499 - auc: 0.6220 - binary_accuracy: 0.7311
# Epoch 00004: val_auc improved from 0.53248 to 0.55774, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00004: val_loss improved from 0.89202 to 0.82460, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 80s 81ms/sample - loss: 0.8503 - auc: 0.6210 - binary_accuracy: 0.7307 - val_loss: 0.8246 - val_auc: 0.5577 - val_binary_accuracy: 0.7400
# Epoch 5/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.8000 - auc: 0.6199 - binary_accuracy: 0.7273
# Epoch 00005: val_auc improved from 0.55774 to 0.58063, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00005: val_loss improved from 0.82460 to 0.79606, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 70s 70ms/sample - loss: 0.7996 - auc: 0.6209 - binary_accuracy: 0.7274 - val_loss: 0.7961 - val_auc: 0.5806 - val_binary_accuracy: 0.7410
# Epoch 6/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.7708 - auc: 0.5945 - binary_accuracy: 0.7258
# Epoch 00006: val_auc did not improve from 0.58063
#
# Epoch 00006: val_loss improved from 0.79606 to 0.75172, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 64s 64ms/sample - loss: 0.7708 - auc: 0.5939 - binary_accuracy: 0.7257 - val_loss: 0.7517 - val_auc: 0.5285 - val_binary_accuracy: 0.7400
# Epoch 7/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.7231 - auc: 0.6155 - binary_accuracy: 0.7321
# Epoch 00007: val_auc improved from 0.58063 to 0.61719, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00007: val_loss improved from 0.75172 to 0.72593, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 87s 88ms/sample - loss: 0.7236 - auc: 0.6143 - binary_accuracy: 0.7317 - val_loss: 0.7259 - val_auc: 0.6172 - val_binary_accuracy: 0.7149
# Epoch 8/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.6922 - auc: 0.6230 - binary_accuracy: 0.7339
# Epoch 00008: val_auc did not improve from 0.61719
#
# Epoch 00008: val_loss improved from 0.72593 to 0.68469, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 60s 60ms/sample - loss: 0.6921 - auc: 0.6230 - binary_accuracy: 0.7342 - val_loss: 0.6847 - val_auc: 0.5866 - val_binary_accuracy: 0.7400
# Epoch 9/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.6691 - auc: 0.6299 - binary_accuracy: 0.7326
# Epoch 00009: val_auc did not improve from 0.61719
#
# Epoch 00009: val_loss improved from 0.68469 to 0.66877, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 57s 57ms/sample - loss: 0.6685 - auc: 0.6312 - binary_accuracy: 0.7324 - val_loss: 0.6688 - val_auc: 0.5596 - val_binary_accuracy: 0.7400
# Epoch 10/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.6450 - auc: 0.6468 - binary_accuracy: 0.7308
# Epoch 00010: val_auc improved from 0.61719 to 0.62165, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00010: val_loss improved from 0.66877 to 0.65909, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 102s 103ms/sample - loss: 0.6447 - auc: 0.6475 - binary_accuracy: 0.7312 - val_loss: 0.6591 - val_auc: 0.6216 - val_binary_accuracy: 0.7189
# Epoch 11/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.6270 - auc: 0.6539 - binary_accuracy: 0.7293
# Epoch 00011: val_auc improved from 0.62165 to 0.64505, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00011: val_loss improved from 0.65909 to 0.61604, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 103s 103ms/sample - loss: 0.6274 - auc: 0.6525 - binary_accuracy: 0.7294 - val_loss: 0.6160 - val_auc: 0.6451 - val_binary_accuracy: 0.7410
# Epoch 12/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.6176 - auc: 0.6473 - binary_accuracy: 0.7306
# Epoch 00012: val_auc did not improve from 0.64505
#
# Epoch 00012: val_loss improved from 0.61604 to 0.61501, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 78s 79ms/sample - loss: 0.6181 - auc: 0.6463 - binary_accuracy: 0.7304 - val_loss: 0.6150 - val_auc: 0.6306 - val_binary_accuracy: 0.7420
# Epoch 13/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5975 - auc: 0.6759 - binary_accuracy: 0.7316
# Epoch 00013: val_auc did not improve from 0.64505
#
# Epoch 00013: val_loss did not improve from 0.61501
# 997/997 [==============================] - 36s 36ms/sample - loss: 0.5972 - auc: 0.6763 - binary_accuracy: 0.7317 - val_loss: 0.7938 - val_auc: 0.5407 - val_binary_accuracy: 0.6837
# Epoch 14/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5861 - auc: 0.6819 - binary_accuracy: 0.7308
# Epoch 00014: val_auc did not improve from 0.64505
#
# Epoch 00014: val_loss did not improve from 0.61501
# 997/997 [==============================] - 26s 26ms/sample - loss: 0.5860 - auc: 0.6818 - binary_accuracy: 0.7309 - val_loss: 0.8601 - val_auc: 0.5623 - val_binary_accuracy: 0.6576
# Epoch 15/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5914 - auc: 0.6630 - binary_accuracy: 0.7306
# Epoch 00015: val_auc did not improve from 0.64505
#
# Epoch 00015: val_loss did not improve from 0.61501
# 997/997 [==============================] - 24s 24ms/sample - loss: 0.5916 - auc: 0.6626 - binary_accuracy: 0.7304 - val_loss: 0.6841 - val_auc: 0.6026 - val_binary_accuracy: 0.6807
# Epoch 16/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5828 - auc: 0.6640 - binary_accuracy: 0.7334
# Epoch 00016: val_auc did not improve from 0.64505
#
# Epoch 00016: val_loss did not improve from 0.61501
# 997/997 [==============================] - 23s 23ms/sample - loss: 0.5827 - auc: 0.6641 - binary_accuracy: 0.7335 - val_loss: 0.6194 - val_auc: 0.5965 - val_binary_accuracy: 0.7400
# Epoch 17/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5756 - auc: 0.6711 - binary_accuracy: 0.7319
# Epoch 00017: val_auc did not improve from 0.64505
#
# Epoch 00017: val_loss improved from 0.61501 to 0.60891, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 63s 63ms/sample - loss: 0.5763 - auc: 0.6694 - binary_accuracy: 0.7319 - val_loss: 0.6089 - val_auc: 0.5992 - val_binary_accuracy: 0.7400
# Epoch 18/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5737 - auc: 0.6716 - binary_accuracy: 0.7321
# Epoch 00018: val_auc did not improve from 0.64505
#
# Epoch 00018: val_loss did not improve from 0.60891
# 997/997 [==============================] - 45s 45ms/sample - loss: 0.5734 - auc: 0.6720 - binary_accuracy: 0.7322 - val_loss: 0.7321 - val_auc: 0.5541 - val_binary_accuracy: 0.6777
# Epoch 19/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5774 - auc: 0.6623 - binary_accuracy: 0.7311
# Epoch 00019: val_auc did not improve from 0.64505
#
# Epoch 00019: val_loss improved from 0.60891 to 0.57482, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 44s 45ms/sample - loss: 0.5773 - auc: 0.6620 - binary_accuracy: 0.7309 - val_loss: 0.5748 - val_auc: 0.6355 - val_binary_accuracy: 0.7400
# Epoch 20/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5592 - auc: 0.6915 - binary_accuracy: 0.7303
# Epoch 00020: val_auc did not improve from 0.64505
#
# Epoch 00020: val_loss did not improve from 0.57482
# 997/997 [==============================] - 31s 31ms/sample - loss: 0.5598 - auc: 0.6900 - binary_accuracy: 0.7304 - val_loss: 0.5894 - val_auc: 0.5941 - val_binary_accuracy: 0.7400
# Epoch 21/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5628 - auc: 0.6762 - binary_accuracy: 0.7319
# Epoch 00021: val_auc improved from 0.64505 to 0.65455, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00021: val_loss improved from 0.57482 to 0.56815, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 70s 70ms/sample - loss: 0.5627 - auc: 0.6765 - binary_accuracy: 0.7319 - val_loss: 0.5681 - val_auc: 0.6546 - val_binary_accuracy: 0.7400
# Epoch 22/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5518 - auc: 0.6975 - binary_accuracy: 0.7336
# Epoch 00022: val_auc did not improve from 0.65455
#
# Epoch 00022: val_loss did not improve from 0.56815
# 997/997 [==============================] - 29s 29ms/sample - loss: 0.5525 - auc: 0.6959 - binary_accuracy: 0.7335 - val_loss: 0.6834 - val_auc: 0.5830 - val_binary_accuracy: 0.6878
# Epoch 23/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5580 - auc: 0.6850 - binary_accuracy: 0.7321
# Epoch 00023: val_auc improved from 0.65455 to 0.66252, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00023: val_loss improved from 0.56815 to 0.56233, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 102s 102ms/sample - loss: 0.5580 - auc: 0.6852 - binary_accuracy: 0.7322 - val_loss: 0.5623 - val_auc: 0.6625 - val_binary_accuracy: 0.7450
# Epoch 24/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5559 - auc: 0.6871 - binary_accuracy: 0.7319
# Epoch 00024: val_auc did not improve from 0.66252
#
# Epoch 00024: val_loss did not improve from 0.56233
# 997/997 [==============================] - 85s 85ms/sample - loss: 0.5559 - auc: 0.6871 - binary_accuracy: 0.7319 - val_loss: 0.7916 - val_auc: 0.5635 - val_binary_accuracy: 0.6616
# Epoch 25/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5527 - auc: 0.6943 - binary_accuracy: 0.7339
# Epoch 00025: val_auc did not improve from 0.66252
#
# Epoch 00025: val_loss improved from 0.56233 to 0.56229, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 83s 83ms/sample - loss: 0.5529 - auc: 0.6938 - binary_accuracy: 0.7340 - val_loss: 0.5623 - val_auc: 0.6544 - val_binary_accuracy: 0.7410
# Epoch 26/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5425 - auc: 0.7092 - binary_accuracy: 0.7387
# Epoch 00026: val_auc did not improve from 0.66252
#
# Epoch 00026: val_loss did not improve from 0.56229
# 997/997 [==============================] - 25s 25ms/sample - loss: 0.5427 - auc: 0.7090 - binary_accuracy: 0.7385 - val_loss: 0.5751 - val_auc: 0.6376 - val_binary_accuracy: 0.7390
# Epoch 27/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5468 - auc: 0.7006 - binary_accuracy: 0.7382
# Epoch 00027: val_auc did not improve from 0.66252
#
# Epoch 00027: val_loss did not improve from 0.56229
# 997/997 [==============================] - 17s 17ms/sample - loss: 0.5471 - auc: 0.6999 - binary_accuracy: 0.7382 - val_loss: 0.5632 - val_auc: 0.6517 - val_binary_accuracy: 0.7430
# Epoch 28/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5431 - auc: 0.7049 - binary_accuracy: 0.7344
# Epoch 00028: val_auc improved from 0.66252 to 0.66528, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00028: val_loss improved from 0.56229 to 0.55603, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_loss5\assets
# 997/997 [==============================] - 92s 92ms/sample - loss: 0.5427 - auc: 0.7054 - binary_accuracy: 0.7347 - val_loss: 0.5560 - val_auc: 0.6653 - val_binary_accuracy: 0.7450
# Epoch 29/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5457 - auc: 0.7025 - binary_accuracy: 0.7351
# Epoch 00029: val_auc improved from 0.66528 to 0.66619, saving model to Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5
# INFO:tensorflow:Assets written to: Z:\Dataset\NN_Dataset\DDSM\Cachelorenzo\checkpoint_auc5\assets
#
# Epoch 00029: val_loss did not improve from 0.55603
# 997/997 [==============================] - 66s 67ms/sample - loss: 0.5456 - auc: 0.7025 - binary_accuracy: 0.7352 - val_loss: 0.5642 - val_auc: 0.6662 - val_binary_accuracy: 0.7440
# Epoch 30/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5383 - auc: 0.7161 - binary_accuracy: 0.7394
# Epoch 00030: val_auc did not improve from 0.66619
#
# Epoch 00030: val_loss did not improve from 0.55603
# 997/997 [==============================] - 25s 25ms/sample - loss: 0.5394 - auc: 0.7147 - binary_accuracy: 0.7392 - val_loss: 0.5943 - val_auc: 0.6074 - val_binary_accuracy: 0.7329
# Epoch 31/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5482 - auc: 0.7024 - binary_accuracy: 0.7366
# Epoch 00031: val_auc did not improve from 0.66619
#
# Epoch 00031: val_loss did not improve from 0.55603
# 997/997 [==============================] - 17s 17ms/sample - loss: 0.5481 - auc: 0.7023 - binary_accuracy: 0.7367 - val_loss: 0.5994 - val_auc: 0.6271 - val_binary_accuracy: 0.7319
# Epoch 32/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5343 - auc: 0.7197 - binary_accuracy: 0.7394
# Epoch 00032: val_auc did not improve from 0.66619
#
# Epoch 00032: val_loss did not improve from 0.55603
# 997/997 [==============================] - 28s 29ms/sample - loss: 0.5343 - auc: 0.7195 - binary_accuracy: 0.7395 - val_loss: 0.5827 - val_auc: 0.6213 - val_binary_accuracy: 0.7359
# Epoch 33/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5364 - auc: 0.7199 - binary_accuracy: 0.7356
# Epoch 00033: val_auc did not improve from 0.66619
#
# Epoch 00033: val_loss did not improve from 0.55603
# 997/997 [==============================] - 32s 33ms/sample - loss: 0.5366 - auc: 0.7193 - binary_accuracy: 0.7357 - val_loss: 0.5717 - val_auc: 0.6465 - val_binary_accuracy: 0.7410
# Epoch 34/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5341 - auc: 0.7221 - binary_accuracy: 0.7346
# Epoch 00034: val_auc did not improve from 0.66619
#
# Epoch 00034: val_loss did not improve from 0.55603
# 997/997 [==============================] - 32s 32ms/sample - loss: 0.5345 - auc: 0.7215 - binary_accuracy: 0.7347 - val_loss: 0.5836 - val_auc: 0.6228 - val_binary_accuracy: 0.7450
# Epoch 35/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5352 - auc: 0.7238 - binary_accuracy: 0.7394
# Epoch 00035: val_auc did not improve from 0.66619
#
# Epoch 00035: val_loss did not improve from 0.55603
# 997/997 [==============================] - 26s 26ms/sample - loss: 0.5351 - auc: 0.7236 - binary_accuracy: 0.7400 - val_loss: 0.6250 - val_auc: 0.6012 - val_binary_accuracy: 0.7209
# Epoch 36/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5503 - auc: 0.7013 - binary_accuracy: 0.7326
# Epoch 00036: val_auc did not improve from 0.66619
#
# Epoch 00036: val_loss did not improve from 0.55603
# 997/997 [==============================] - 26s 27ms/sample - loss: 0.5501 - auc: 0.7015 - binary_accuracy: 0.7327 - val_loss: 0.5660 - val_auc: 0.6459 - val_binary_accuracy: 0.7369
# Epoch 37/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5453 - auc: 0.7106 - binary_accuracy: 0.7291
# Epoch 00037: val_auc did not improve from 0.66619
#
# Epoch 00037: val_loss did not improve from 0.55603
# 997/997 [==============================] - 21s 22ms/sample - loss: 0.5446 - auc: 0.7116 - binary_accuracy: 0.7289 - val_loss: 0.5835 - val_auc: 0.6178 - val_binary_accuracy: 0.7440
# Epoch 38/50
# 992/997 [============================>.] - ETA: 0s - loss: 0.5330 - auc: 0.7277 - binary_accuracy: 0.7399
# Epoch 00038: val_auc did not improve from 0.66619
#
# Epoch 00038: val_loss did not improve from 0.55603
# 997/997 [==============================] - 23s 24ms/sample - loss: 0.5327 - auc: 0.7280 - binary_accuracy: 0.7397 - val_loss: 0.6815 - val_auc: 0.5941 - val_binary_accuracy: 0.7028
# 'y={"lb":labels["lb"],\n    "lm":labels["lm"],\n    "rm":labels["rm"],\n    "rb":labels["rb"]}\n    \n'

# %%
for i in history.history.keys():
  if "val" in i:
    continue
  # plot loss during training
  pyplot.subplot(211)
  pyplot.title(i)
  pyplot.plot(history.history[i], label='train')
  pyplot.plot(history.history['val_'+i], label='test')
  pyplot.show()

# %% [markdown]
# <h2> Writing CSV (1-5)</h2>

# %%
with open(directory+'/training_5.csv', 'w', newline='') as file:

  writer = csv.writer(file)

  for number in numbers1:
    for folder in folders:
      for i,j,y in os.walk(directory2+folder+number,topdown=False):
        
        if(j):
          for name in j:
            left_cc=""
            left_mlo=""
            right_cc=""
            right_mlo=""
            lb="0"
            rb="0"
            lm="0"
            rm="0"
            case=name
            for i2,j2,y2 in os.walk(i+name,topdown=False):
              for name2 in y2:
                if "LEFT_CC.png" in name2:
                  left_cc=i2+"/"+name2
                if "LEFT_MLO.png" in name2:
                  left_mlo=i2+"/"+name2
                if "RIGHT_CC.png" in name2:
                  right_cc= i2+"/"+name2
                if "RIGHT_MLO.png" in name2:
                  right_mlo=i2+"/"+name2

                if "benign" in folder:
                  if name2.endswith(".OVERLAY"):
                    if "LEFT" in name2:
                      lb="1"
                    if "RIGHT" in name2:
                      rb="1"
                if "cancer" in folder:
                  if name2.endswith(".OVERLAY"):
                    if "LEFT" in name2:
                      lm="1"
                    if "RIGHT" in name2:
                      rm="1"
            if(left_cc!="" and right_cc!="" and right_mlo!="" and left_mlo!=""):
                writer.writerow([case,left_cc,left_mlo,right_cc,right_mlo,lb,lm,rb,rm])

# %%
with open(directory+'/validation_5.csv', 'w', newline='') as file:

  writer = csv.writer(file)

  for folder in folders:
    for number in numbers2:
      for i,j,y in os.walk(directory2+folder+number,topdown=False):
        
        if(j):
          for name in j:
            left_cc=""
            left_mlo=""
            right_cc=""
            right_mlo=""
            lb="0"
            rb="0"
            
            lm="0"
            rm="0"
            case=name
            for i2,j2,y2 in os.walk(i+name,topdown=False):
              for name2 in y2:
                if "LEFT_CC.png" in name2:
                  left_cc=i2+"/"+name2
                if "LEFT_MLO.png" in name2:
                  left_mlo=i2+"/"+name2
                if "RIGHT_CC.png" in name2:
                  right_cc= i2+"/"+name2
                if "RIGHT_MLO.png" in name2:
                  right_mlo=i2+"/"+name2

                if "benign" in folder:
                  if name2.endswith(".OVERLAY"):
                    if "LEFT" in name2:
                      lb="1"
                    if "RIGHT" in name2:
                      rb="1"
                if "cancer" in folder:
                  if name2.endswith(".OVERLAY"):
                    if "LEFT" in name2:
                      lm="1"
                    if "RIGHT" in name2:
                      rm="1"
            if(left_cc!="" and right_cc!="" and right_mlo!="" and left_mlo!=""):
                writer.writerow([case,left_cc,left_mlo,right_cc,right_mlo,lb,lm,rb,rm])
